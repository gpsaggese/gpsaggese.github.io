# %% [markdown]
# # LangChain API Tutorial
#
# This tutorial demonstrates how to use LangChain's core functionalities.
# LangChain is a powerful framework designed to facilitate building language model-powered applications.
# We'll explore its components, including prompt creation, chains, retrieval, and agents.

# %%
import requests

resp = requests.post("http://host.docker.internal:11434/api/generate", json={
    "model": "gemma3",
    "prompt": "what is the e constant, euler",
    "stream": False
})
print(resp.json())
# Out:
# {'model': 'gemma3', 'created_at': '2025-08-20T01:03:33.481943Z', 'response': 'Okay, let\'s break down what the *e* constant (Euler\'s number) is. It\'s a truly special and fundamental number in mathematics.\n\n**1. What is *e*?**\n\n*e* (pronounced "e") is an irrational and transcendental number, approximately equal to 2.71828. This means:\n   * **Irrational:**  Its decimal representation goes on forever without repeating. You can\'t write it as a simple fraction (a/b, where a and b are integers).\n   * **Transcendental:** It\'s *not* the root of any polynomial equation with integer coefficients. This distinguishes it from algebraic numbers like √2.\n\n**2. Where Does *e* Come From?**\n\n*e* arises naturally from the concept of **continuous compounding** and **exponential growth**.  Here\'s a simple way to think about it:\n\nImagine you invest $1 at an interest rate of 100% per year. After one year, you\'d have $2. After two years, you\'d have $2 * 2 = $4. After three years, you\'d have $4 * 2 = $8, and so on.  If the interest compounded continuously (meaning it\'s calculated and added to the principal continuously), the amount you\'d have after *t* years is given by:\n\nA = P * e^(rt)\n\nWhere:\n\n*   A = the amount after *t* years\n*   P = the principal amount (initial investment)\n*   r = the interest rate (as a decimal)\n*   t = time in years\n\n*e* is the value that solves the equation A = P when r = 1. In other words, if you invest $1 at 100% interest per year, *e* is the amount you\'ll have after one year.\n\n\n**3.  Key Properties and Significance**\n\n*   **Natural Logarithm:** *e* is the base of the natural logarithm (ln). The natural logarithm is the logarithm with base *e*.  The natural log of a number *x* is the power to which you must raise *e* to get *x*.\n\n*   **Exponential Growth/Decay:**  *e* appears extensively in models of exponential growth and decay in various fields, including:\n    *   **Population growth**\n    *   **Radioactive decay**\n    *   **Compound interest**\n    *   **Spread of diseases**\n\n*   **Calculus:** *e* is incredibly important in calculus.  The exponential function e^x has a constant derivative of itself, which makes it a fundamental function for integration and differentiation.\n\n**4.  Euler\'s Number (Leonhard Euler)**\n\nThe number *e* is named after the brilliant mathematician Leonhard Euler (1707-1783). He extensively studied *e* and its properties, and it\'s why it\'s often referred to as "Euler\'s number".\n\n**In Summary:**\n\n*e* is a fundamental mathematical constant that arises from continuous growth, has unique properties, and appears in a vast number of mathematical and scientific applications. It\'s a truly remarkable number!\n\nDo you want me to delve into any specific aspect of *e* in more detail, such as:\n\n*   The formula for the natural logarithm?\n*   How *e* is used in specific applications (like population growth)?', 'done': True, 'done_reason': 'stop', 'context': [105, 2364, 107, 14070, 563, 506, 545, 4512, 236764, 545, 13266, 106, 107, 105, 4368, 107, 19058, 236764, 1531, 236789, 236751, 2541, 1679, 1144, 506, 808, 236744, 236829, 4512, 568, 95131, 236789, 236751, 1548, 236768, 563, 236761, 1030, 236789, 236751, 496, 9995, 2803, 532, 11001, 1548, 528, 29282, 236761, 108, 1018, 236770, 236761, 2900, 563, 808, 236744, 236829, 236881, 1018, 108, 236829, 236744, 236829, 568, 170196, 623, 236744, 1373, 563, 614, 67208, 532, 136434, 1548, 236764, 8296, 4745, 531, 236743, 236778, 236761, 236832, 236770, 236828, 236778, 236828, 236761, 1174, 2820, 236787, 107, 139, 236829, 5213, 203314, 1353, 53121, 138, 34520, 20632, 10065, 5899, 580, 17504, 2180, 43064, 236761, 1599, 740, 236789, 236745, 4903, 625, 618, 496, 3606, 10742, 568, 236746, 236786, 236763, 236764, 1298, 496, 532, 518, 659, 25630, 769, 107, 139, 236829, 5213, 5183, 126820, 5033, 53121, 1030, 236789, 236751, 808, 2217, 236829, 506, 5989, 529, 1027, 14337, 4901, 607, 11995, 15841, 236761, 1174, 88906, 625 ...
