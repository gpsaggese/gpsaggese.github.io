# %% [markdown]
# ## Imports

# %%
import sys, os
sys.path.append("/workspace") 
sys.path.append("/workspace/helpers_root") 
sys.path.append("/workspace/msml610/tutorials") 
os.environ["CSFY_GIT_ROOT_PATH"] = "/workspace/msml610"

# %% [markdown]
# ### Install packages

# %%
# !sudo /bin/bash -c "(source /venv/bin/activate; pip install --quiet jupyterlab-vim)"
# !jupyter labextension enable

# %%
# !sudo /bin/bash -c "(source /venv/bin/activate; pip install --quiet graphviz)"

# %%
# !sudo /bin/bash -c "(source /venv/bin/activate; pip install --quiet dataframe_image)"

# %%
pip install arviz
# Out:
# Requirement already satisfied: arviz in /venv/lib/python3.12/site-packages (0.22.0)
# Requirement already satisfied: setuptools>=60.0.0 in /venv/lib/python3.12/site-packages (from arviz) (80.9.0)
# Requirement already satisfied: matplotlib>=3.8 in /venv/lib/python3.12/site-packages (from arviz) (3.10.7)
# Requirement already satisfied: numpy>=1.26.0 in /venv/lib/python3.12/site-packages (from arviz) (2.3.5)
# Requirement already satisfied: scipy>=1.11.0 in /venv/lib/python3.12/site-packages (from arviz) (1.16.3)
# Requirement already satisfied: packaging in /venv/lib/python3.12/site-packages (from arviz) (25.0)
# Requirement already satisfied: pandas>=2.1.0 in /venv/lib/python3.12/site-packages (from arviz) (2.3.3)
# Requirement already satisfied: xarray>=2023.7.0 in /venv/lib/python3.12/site-packages (from arviz) (2025.11.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /venv/lib/python3.12/site-packages (from arviz) (1.7.3)
# Requirement already satisfied: typing-extensions>=4.1.0 in /venv/lib/python3.12/site-packages (from arviz) (4.15.0)
# Requirement already satisfied: xarray-einstats>=0.3 in /venv/lib/python3.12/site-packages (from arviz) (0.9.1)
# Requirement already satisfied: h5py in /venv/lib/python3.12/site-packages (from h5netcdf>=1.0.2->arviz) (3.15.1)
# Requirement already satisfied: contourpy>=1.0.1 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz) (1.4.9)
# Requirement already satisfied: pillow>=8 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /venv/lib/python3.12/site-packages (from pandas>=2.1.0->arviz) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /venv/lib/python3.12/site-packages (from pandas>=2.1.0->arviz) (2025.2)
# Requirement already satisfied: six>=1.5 in /venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.8->arviz) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install pymc
# Out:
# Collecting pymc
#   Downloading pymc-5.26.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: arviz>=0.13.0 in /venv/lib/python3.12/site-packages (from pymc) (0.22.0)
# Collecting cachetools>=4.2.1 (from pymc)
#   Downloading cachetools-6.2.2-py3-none-any.whl.metadata (5.6 kB)
# Collecting cloudpickle (from pymc)
#   Downloading cloudpickle-3.1.2-py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: numpy>=1.25.0 in /venv/lib/python3.12/site-packages (from pymc) (2.3.5)
# Requirement already satisfied: pandas>=0.24.0 in /venv/lib/python3.12/site-packages (from pymc) (2.3.3)
# Collecting pytensor<2.36,>=2.35.0 (from pymc)
#   Downloading pytensor-2.35.1-py2.py3-none-any.whl.metadata (6.8 kB)
# Collecting rich>=13.7.1 (from pymc)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: scipy>=1.4.1 in /venv/lib/python3.12/site-packages (from pymc) (1.16.3)
# Requirement already satisfied: threadpoolctl<4.0.0,>=3.1.0 in /venv/lib/python3.12/site-packages (from pymc) (3.6.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /venv/lib/python3.12/site-packages (from pymc) (4.15.0)
# Requirement already satisfied: setuptools>=60.0.0 in /venv/lib/python3.12/site-packages (from arviz>=0.13.0->pymc) (80.9.0)
# Requirement already satisfied: matplotlib>=3.8 in /venv/lib/python3.12/site-packages (from arviz>=0.13.0->pymc) (3.10.7)
# Requirement already satisfied: packaging in /venv/lib/python3.12/site-packages (from arviz>=0.13.0->pymc) (25.0)
# Requirement already satisfied: xarray>=2023.7.0 in /venv/lib/python3.12/site-packages (from arviz>=0.13.0->pymc) (2025.11.0)
# Requirement already satisfied: h5netcdf>=1.0.2 in /venv/lib/python3.12/site-packages (from arviz>=0.13.0->pymc) (1.7.3)
# Requirement already satisfied: xarray-einstats>=0.3 in /venv/lib/python3.12/site-packages (from arviz>=0.13.0->pymc) (0.9.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /venv/lib/python3.12/site-packages (from pandas>=0.24.0->pymc) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /venv/lib/python3.12/site-packages (from pandas>=0.24.0->pymc) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /venv/lib/python3.12/site-packages (from pandas>=0.24.0->pymc) (2025.2)
# Collecting filelock>=3.15 (from pytensor<2.36,>=2.35.0->pymc)
#   Using cached filelock-3.20.0-py3-none-any.whl.metadata (2.1 kB)
# Collecting etuples (from pytensor<2.36,>=2.35.0->pymc)
#   Downloading etuples-0.3.10-py3-none-any.whl.metadata (4.8 kB)
# Collecting logical-unification (from pytensor<2.36,>=2.35.0->pymc)
#   Downloading logical_unification-0.4.7-py3-none-any.whl.metadata (15 kB)
# Collecting miniKanren (from pytensor<2.36,>=2.35.0->pymc)
#   Downloading minikanren-1.0.5-py3-none-any.whl.metadata (7.6 kB)
# Collecting cons (from pytensor<2.36,>=2.35.0->pymc)
#   Downloading cons-0.4.7-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /venv/lib/python3.12/site-packages (from rich>=13.7.1->pymc) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /venv/lib/python3.12/site-packages (from rich>=13.7.1->pymc) (2.19.2)
# Requirement already satisfied: h5py in /venv/lib/python3.12/site-packages (from h5netcdf>=1.0.2->arviz>=0.13.0->pymc) (3.15.1)
# Requirement already satisfied: mdurl~=0.1 in /venv/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=13.7.1->pymc) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz>=0.13.0->pymc) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz>=0.13.0->pymc) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz>=0.13.0->pymc) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz>=0.13.0->pymc) (1.4.9)
# Requirement already satisfied: pillow>=8 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz>=0.13.0->pymc) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /venv/lib/python3.12/site-packages (from matplotlib>=3.8->arviz>=0.13.0->pymc) (3.2.5)
# Requirement already satisfied: six>=1.5 in /venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas>=0.24.0->pymc) (1.17.0)
# Collecting toolz (from logical-unification->pytensor<2.36,>=2.35.0->pymc)
#   Downloading toolz-1.1.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting multipledispatch (from logical-unification->pytensor<2.36,>=2.35.0->pymc)
#   Downloading multipledispatch-1.0.0-py3-none-any.whl.metadata (3.8 kB)
# Downloading pymc-5.26.1-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.7/536.7 kB 13.4 MB/s eta 0:00:00a 0:00:01
# Downloading cachetools-6.2.2-py3-none-any.whl (11 kB)
# Downloading pytensor-2.35.1-py2.py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 24.5 MB/s eta 0:00:00a 0:00:01
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 21.8 MB/s eta 0:00:00
# Downloading cloudpickle-3.1.2-py3-none-any.whl (22 kB)
# Using cached filelock-3.20.0-py3-none-any.whl (16 kB)
# Downloading cons-0.4.7-py3-none-any.whl (8.6 kB)
# Downloading logical_unification-0.4.7-py3-none-any.whl (13 kB)
# Downloading etuples-0.3.10-py3-none-any.whl (12 kB)
# Downloading minikanren-1.0.5-py3-none-any.whl (24 kB)
# Downloading multipledispatch-1.0.0-py3-none-any.whl (12 kB)
# Downloading toolz-1.1.0-py3-none-any.whl (58 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 13.8 MB/s eta 0:00:00
# Installing collected packages: multipledispatch, toolz, filelock, cloudpickle, cachetools, rich, logical-unification, cons, etuples, miniKanren, pytensor, pymc
# Successfully installed cachetools-6.2.2 cloudpickle-3.1.2 cons-0.4.7 etuples-0.3.10 filelock-3.20.0 logical-unification-0.4.7 miniKanren-1.0.5 multipledispatch-1.0.0 pymc-5.26.1 pytensor-2.35.1 rich-14.2.0 toolz-1.1.0
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install preliz
# Out:
# Collecting preliz
#   Downloading preliz-0.23.0-py3-none-any.whl.metadata (6.2 kB)
# Collecting arviz_stats>=0.6.0 (from preliz)
#   Downloading arviz_stats-0.7.0-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: matplotlib>=3.9 in /venv/lib/python3.12/site-packages (from preliz) (3.10.7)
# Collecting numba>=0.62 (from preliz)
#   Downloading numba-0.62.1-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl.metadata (2.8 kB)
# Requirement already satisfied: numpy>=2.0 in /venv/lib/python3.12/site-packages (from preliz) (2.3.5)
# Requirement already satisfied: scipy>=1.12 in /venv/lib/python3.12/site-packages (from preliz) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /venv/lib/python3.12/site-packages (from matplotlib>=3.9->preliz) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /venv/lib/python3.12/site-packages (from matplotlib>=3.9->preliz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /venv/lib/python3.12/site-packages (from matplotlib>=3.9->preliz) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /venv/lib/python3.12/site-packages (from matplotlib>=3.9->preliz) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /venv/lib/python3.12/site-packages (from matplotlib>=3.9->preliz) (25.0)
# Requirement already satisfied: pillow>=8 in /venv/lib/python3.12/site-packages (from matplotlib>=3.9->preliz) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /venv/lib/python3.12/site-packages (from matplotlib>=3.9->preliz) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /venv/lib/python3.12/site-packages (from matplotlib>=3.9->preliz) (2.9.0.post0)
# Collecting llvmlite<0.46,>=0.45.0dev0 (from numba>=0.62->preliz)
#   Downloading llvmlite-0.45.1-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl.metadata (4.9 kB)
# Requirement already satisfied: six>=1.5 in /venv/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.9->preliz) (1.17.0)
# Downloading preliz-0.23.0-py3-none-any.whl (529 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 529.2/529.2 kB 2.4 MB/s eta 0:00:00a 0:00:01
# Downloading arviz_stats-0.7.0-py3-none-any.whl (148 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.0/149.0 kB 3.5 MB/s eta 0:00:00a 0:00:01
# Downloading numba-0.62.1-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (3.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.5/3.5 MB 6.5 MB/s eta 0:00:0000:0100:01
# Downloading llvmlite-0.45.1-cp312-cp312-manylinux_2_27_aarch64.manylinux_2_28_aarch64.whl (55.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 MB 17.7 MB/s eta 0:00:0000:0100:01
# Installing collected packages: llvmlite, numba, arviz_stats, preliz
# Successfully installed arviz_stats-0.7.0 llvmlite-0.45.1 numba-0.62.1 preliz-0.23.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Import modules

# %%
# %load_ext autoreload
# %autoreload 2

import logging

import arviz as az
import pandas as pd
import xarray as xr
import pymc as pm
import numpy as np
import seaborn as sns
import scipy.stats as stats
import matplotlib.pyplot as plt
import preliz as pz
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
dir_name = "./Lesson07-data"

# !ls $dir_name
# Out:
# anscombe.csv	     chemical_shifts_theo_exp.csv  islands.csv
# anscombe_3.csv	     coal.csv			   penguins.csv
# babies.csv	     dummy.csv			   pigs.csv
# bikes.csv	     fish.csv			   redwood.csv
# bikes_full.csv	     football_players.csv	   space_flu.csv
# body_fat.csv	     horseshoe_crab.csv		   tips.csv
# body_fat_full.csv    howell.csv
# chemical_shifts.csv  iris.csv

# %%
import msml610_utils as ut

ut.config_notebook()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 import msml610_utils as ut
#       3 ut.config_notebook()
#
# File /workspace/msml610/tutorials/msml610_utils.py:14
#      11 import ipywidgets as W
#      12 from IPython.display import clear_output, display
# ---> 14 import helpers.hdbg as hdbg
#      17 _LOG = logging.getLogger(__name__)
#      20 def set_notebook_style() -> None:
#
# ModuleNotFoundError: No module named 'helpers'

# %% [markdown]
# # Chemical Shift

# %% [markdown]
# ## Gaussian inference

# %%
data = np.loadtxt(f"{dir_name}/chemical_shifts.csv")
print(len(data), data)
#print(sorted(data))

# It looks Gaussian with a couple of outliers.
az.plot_kde(data, rug=True)

title = "Chemical shift"
ut.process_figure(title);
# Out:
# 48 [51.06 55.12 53.73 50.24 52.05 56.4  48.45 52.34 55.65 51.49 51.86 63.43
#  53.   56.09 51.93 52.31 52.33 57.48 57.44 55.14 53.93 54.62 56.09 68.58
#  51.36 55.47 50.73 51.94 54.95 50.39 52.91 51.5  52.68 47.72 49.73 51.82
#  54.99 52.84 53.19 54.52 51.46 53.73 51.61 49.81 52.42 54.3  53.84 53.16]
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[20], line 9
#       6 az.plot_kde(data, rug=True)
#       8 title = "Chemical shift"
# ----> 9 ut.process_figure(title);
#
# NameError: name 'ut' is not defined

# %%
with pm.Model() as model_g:
    # The mean is Uniform in [40, 70] (which is larger than the data).
    mu = pm.Uniform("mu", lower=40, upper=70)
    # The std dev is half normal with a large value (which is a large value based on the data).
    sigma = pm.HalfNormal("sigma", sigma=10)
    # The model is N(mu, sigma).
    y = pm.Normal("y", mu=mu, sigma=sigma, observed=data)
    # Sample.
    idata_g = pm.sample(1000)
# Out:
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [mu, sigma]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 1 seconds.

# %%
pm.model_to_graphviz(model_g)

# %%
# There are 4 traces for 2 variables.
az.plot_trace(idata_g);

# %%
# The posterior distribution of the params is bi-dimensional, since it has mu and sigma.
az.plot_pair(idata_g, kind='kde', marginals=True);

# %%
# Report a summary of the inference.
az.summary(idata_g, kind="stats").round(2)
# Out:
#         mean    sd  hdi_3%  hdi_97%
# mu     53.50  0.51   52.57    54.49
# sigma   3.54  0.37    2.92     4.28

# %%
# Compute 100 posterior predictive samples.
y_pred_g = pm.sample_posterior_predictive(idata_g, model=model_g)
# Out:
# Sampling: [y]
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
# Black: KDE of the data (observed)
# Blue: KDEs of the posterior predictive samples
# Orange: KDE of the posterior predictive mean
az.plot_ppc(y_pred_g, mean=True, num_pp_samples=100);

# %% [markdown]
# ## Student-t

# %%
# Show the PDF for various values of \nu.

# Points to be used to sample the PDF.
x_values = np.linspace(-10, 10, 500)

# Plot t-student sweeping \nu.
for df in [0.1, 0.5, 1, 2, 5, 10, 30]:
    # Student-t with df.
    distr = stats.t(df)
    # Compute PDF.
    x_pdf = distr.pdf(x_values)
    plt.plot(x_values, x_pdf, label=f"nu={df}")
    
# Plot gaussian.
x_pdf = stats.norm.pdf(x_values)
plt.plot(x_values, x_pdf, "k--", label="Gauss / nu=infty")

plt.xlim(-5, 5) 
plt.legend();

title = "Chap7: Student-t"
ut.process_figure(title);
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 22
#      19 plt.legend();
#      21 title = "Chap7: Student-t"
# ---> 22 ut.process_figure(title);
#
# NameError: name 'ut' is not defined

# %%
# Use a Student-T model.
with pm.Model() as model_t:
    mu = pm.Uniform("mu", 40, 75)
    sigma = pm.HalfNormal("sigma", sigma=10)
    # A student with nu = 30 is close to a Gaussian.
    nu = pm.Exponential("nu", 1/30)
    #
    y = pm.StudentT("y", mu=mu, sigma=sigma, nu=nu, observed=data)
    idata_t = pm.sample(1_000)

# %%
az.plot_trace(idata_t);

# %%
az.summary(idata_t, kind="stats").round(2)

# %%
# Compute 100 posterior predictive samples.
y_ppc_t = pm.sample_posterior_predictive(idata_t, model_t);

# %%
ax = az.plot_ppc(y_ppc_t, num_pp_samples=100, mean=True)
ax.set_xlim(40, 70);
