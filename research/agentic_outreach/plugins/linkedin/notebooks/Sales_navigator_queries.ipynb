# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import logging

import pandas as pd

# /venv/lib/python3.12/site-packages/gspread_pandas/spread.py:401: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)` .replace("", np.nan)
pd.set_option("future.no_silent_downcasting", True)

import helpers.hdbg as hdbg
import helpers.henv as henv
import helpers.hprint as hprint

hdbg.init_logger(verbosity=logging.INFO)

_LOG = logging.getLogger(__name__)
_LOG.info("%s", henv.get_system_signature()[0])

hnotebook.config_notebook()
# Out:
# WARNING: Running in Jupyter
# INFO  > cmd='/venv/lib/python3.12/site-packages/ipykernel_launcher.py -f /home/.local/share/jupyter/runtime/kernel-9ad8c25d-6252-4632-827a-b57f03a8f931.json'
#
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (arm64v8)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/
#
# INFO  # System signature
#   # Container version
#     container_version='2.0.0'
#     changelog_version='2.2.0'
#   # Git info
#     branch_name='CsfyTask7819_Add_blogs'
#     hash='2b64a6ee5c'
#     # Last commits:
#       * 2b64a6ee5c GP Saggese Update                                                            (    2 days ago) Thu Dec 25 01:55:48 2025  (HEAD -> CsfyTask7819_Add_blogs, origin/CsfyTask7819_Add_blogs)
#       * 3cfa583380 GP Saggese Update                                                            (    2 days ago) Thu Dec 25 01:47:58 2025
#       * 683e50c1fc GP Saggese Update                                                            (    2 days ago) Thu Dec 25 00:45:57 2025
#   # Platform info
#     system=Linux
#     node name=760242bdb197
#     release=6.10.14-linuxkit
#     version=#1 SMP Tue Apr 15 16:00:54 UTC 2025
#     machine=aarch64
#     processor=aarch64
#   # psutils info
#     cpu count=8
#     cpu freq=None
#     memory=svmem(total=16749285376, available=14497411072, percent=13.4, used=1988976640, free=12505440256, active=2910011392, inactive=881651712, buffers=318332928, cached=1936535552, shared=876544, slab=294211584)
#     disk usage=sdiskusage(total=270233210880, used=154694836224, free=101777760256, percent=60.3)
#   # Docker info
#     has_docker=True
#     docker_version='28.1.1'
#     docker_needs_sudo=False
#     has_privileged_mode=True
#     is_inside_docker=True
#     has_sibling_containers_support=True
#     has_docker_dind_support=True
#   # Packages
#     python: 3.12.3
#     cvxopt: 1.3.2
#     cvxpy: 1.5.3
#     gluonnlp: ?
#     gluonts: ?
#     joblib: 1.4.2
#     mxnet: ?
#     numpy: 2.1.3
#     pandas: 2.2.3
#     pyarrow: 18.0.0
#     scipy: 1.14.1
#     seaborn: 0.13.2
#     sklearn: 1.5.2
#     statsmodels: 0.14.4

# %%
# !pwd
# Out:
# /app/ck_marketing/plugins/linkedin/notebooks

# %%
file_name = "/app/ck_marketing/plugins/linkedin/industry_codes_v2.csv"
df = pd.read_csv(file_name)
df.set_index("id", inplace=True)
df.head(3)

# df["label"].to_dict()
# Out:
#                                label                                          hierarchy                                        description
# id
# 1    Defense and Space Manufacturing  Manufacturing > Transportation Equipment Manuf...  This industry includes entities that manufactu...
# 10                    Legal Services             Professional Services > Legal Services  This industry includes entities that offer leg...
# 100         Non-profit Organizations       Consumer Services > Non-profit Organizations  This industry includes entities that provide p...

# %%
# Company headcount
# 51-200
# 201-500
# 501-1000
# 1001-5000
# 5001-10,000

# Company type
# Public Company
# Privately Held

# Persona: CXO
# CXO
# Owner / Partner
# Director

# Geography
# North America
url = "https://www.linkedin.com/sales/search/people?query=(recentSearchParam%3A(id%3A4154025850%2CdoLogHistory%3Atrue)%2Cfilters%3AList((type%3ACOMPANY_TYPE%2Cvalues%3AList((id%3AC%2Ctext%3APublic%2520Company%2CselectionType%3AINCLUDED)%2C(id%3AP%2Ctext%3APrivately%2520Held%2CselectionType%3AINCLUDED)))%2C(type%3APERSONA%2Cvalues%3AList((id%3A50605714%2Ctext%3ACXO%2CselectionType%3AINCLUDED)))%2C(type%3AREGION%2Cvalues%3AList((id%3A102221843%2Ctext%3ANorth%2520America%2CselectionType%3AINCLUDED)))%2C(type%3ACOMPANY_HEADCOUNT%2Cvalues%3AList((id%3AD%2Ctext%3A51-200%2CselectionType%3AINCLUDED)%2C(id%3AE%2Ctext%3A201-500%2CselectionType%3AINCLUDED)%2C(id%3AF%2Ctext%3A501-1%252C000%2CselectionType%3AINCLUDED)%2C(id%3AG%2Ctext%3A1%252C001-5%252C000%2CselectionType%3AINCLUDED)%2C(id%3AH%2Ctext%3A5%252C001-10%252C000%2CselectionType%3AINCLUDED)))))&sessionId=0s9aiKiDQs29Zer3baFHIw%3D%3D&viewAllFilters=true"

# %%
import ck_marketing.plugins as ckmktpi

import importlib

importlib.reload(ckmktpi)
# Out:
# <module 'ck_marketing.plugins' from '/app/ck_marketing/plugins/__init__.py'>

# %%
url = "https://www.linkedin.com/sales/search/people?query=(recentSearchParam%3A(id%3A5116736402%2CdoLogHistory%3Atrue)%2Cfilters%3AList((type%3ACOMPANY_HEADCOUNT%2Cvalues%3AList((id%3AI%2Ctext%3A10%252C000%252B%2CselectionType%3AINCLUDED)))%2C(type%3ACURRENT_TITLE%2Cvalues%3AList((text%3AMergers%2520and%2520Acquisitions%2CselectionType%3AINCLUDED)%2C(text%3AM%2526A%2CselectionType%3AINCLUDED)%2C(text%3ACorporate%2520Development%2CselectionType%3AINCLUDED)%2C(text%3ACorp%2520Dev%2CselectionType%3AINCLUDED)))%2C(type%3ASENIORITY_LEVEL%2Cvalues%3AList((id%3A310%2Ctext%3ACXO%2CselectionType%3AINCLUDED)%2C(id%3A300%2Ctext%3AVice%2520President%2CselectionType%3AINCLUDED)%2C(id%3A220%2Ctext%3ADirector%2CselectionType%3AINCLUDED)%2C(id%3A320%2Ctext%3AOwner%2520%252F%2520Partner%2CselectionType%3AINCLUDED)))%2C(type%3AREGION%2Cvalues%3AList((id%3A102221843%2Ctext%3ANorth%2520America%2CselectionType%3AINCLUDED)))%2C(type%3AYEARS_IN_CURRENT_POSITION%2Cvalues%3AList((id%3A2%2Ctext%3A1%2520to%25202%2520years%2CselectionType%3AINCLUDED)%2C(id%3A3%2Ctext%3A3%2520to%25205%2520years%2CselectionType%3AINCLUDED)%2C(id%3A4%2Ctext%3A6%2520to%252010%2520years%2CselectionType%3AINCLUDED)%2C(id%3A5%2Ctext%3AMore%2520than%252010%2520years%2CselectionType%3AINCLUDED)))))&sessionId=CZqz%2BZ75RriV0TlA4%2FHKew%3D%3D&viewAllFilters=true"

import pprint

result = ckmktpi.parse_query(url)
result = result["filters"]
# print(json.dumps(result, indent=2))
pprint.pprint(result)
# Out:
# {'COMPANY_HEADCOUNT': [{'id': 'I',
#                         'selectionType': 'INCLUDED',
#                         'text': '10,000+'}],
#  'CURRENT_TITLE': [{'selectionType': 'INCLUDED',
#                     'text': 'Mergers and Acquisitions'},
#                    {'selectionType': 'INCLUDED', 'text': 'M&A'},
#                    {'selectionType': 'INCLUDED',
#                     'text': 'Corporate Development'},
#                    {'selectionType': 'INCLUDED', 'text': 'Corp Dev'}],
#  'REGION': [{'id': '102221843',
#              'selectionType': 'INCLUDED',
#              'text': 'North America'}],
#  'SENIORITY_LEVEL': [{'id': '310', 'selectionType': 'INCLUDED', 'text': 'CXO'},
#                      {'id': '300',
#                       'selectionType': 'INCLUDED',
#                       'text': 'Vice President'},
#                      {'id': '220',
#                       'selectionType': 'INCLUDED',
#                       'text': 'Director'},
#                      {'id': '320',
#                       'selectionType': 'INCLUDED',
#                       'text': 'Owner / Partner'}],
#  'YEARS_IN_CURRENT_POSITION': [{'id': '2',
#                                 'selectionType': 'INCLUDED',
#                                 'text': '1 to 2 years'},
#                                {'id': '3',
#                                 'selectionType': 'INCLUDED',
#                                 'text': '3 to 5 years'},
#                                {'id': '4',
#                                 'selectionType': 'INCLUDED',
#                                 'text': '6 to 10 years'},
#                                {'id': '5',
#                                 'selectionType': 'INCLUDED',
#                                 'text': 'More than 10 years'}]}
