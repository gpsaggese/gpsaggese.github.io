# %% [markdown]
# # Imports

# %%
# !sudo /bin/bash -c "(source /venv/bin/activate; pip install --quiet jupyterlab-vim)"
# !jupyter labextension enable

#!sudo /bin/bash -c "(source /venv/bin/activate; pip install --quiet --upgrade google-api-python-client)"

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# !cd /app

# %%
import logging

import helpers.hdbg as hdbg
import helpers.henv as henv
import helpers.hprint as hprint

hdbg.init_logger(verbosity=logging.INFO)
_LOG = logging.getLogger(__name__)
_LOG.info("%s", henv.get_system_signature()[0])

hnotebook.config_notebook()
# Out:
# WARNING: Running in Jupyter
# INFO  > cmd='/venv/lib/python3.12/site-packages/ipykernel_launcher.py -f /home/.local/share/jupyter/runtime/kernel-8f966726-1c77-4f94-8450-d5f3200f1863.json'
#
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (arm64v8)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
# ...

# %%
import helpers.hgoogle_drive_api as hgodrapi
import helpers.hpandas as hpandas

# Get credentials.
credentials = hgodrapi.get_credentials(
    service_key_path="/home/.config/gspread_pandas/google_secret.json"
)

# %%
import importlib

import ck_marketing.workflows as ckmktwf

importlib.reload(ckmktwf)
# Out:
# /app/ck_marketing/workflows/data_loaders_specific.py:14: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# <module 'ck_marketing.workflows' from '/app/ck_marketing/workflows/__init__.py'>

# %%
db_path = "test.sql"

# %%
if True:
    # delete_existing_db = False
    delete_existing_db = True
    ckmktwf.create_db(
        db_path, delete_existing_db=delete_existing_db
    )  # , log_level=logging.INFO)
# Out:
# INFO  Initializing database at: test.sql
# WARNING Creating database from scratch
# Are you sure you want to create the database from scratch? [y/n]
#  y
# INFO  Database initialized at: test.sql

# %% [markdown]
# ## Print all schema

# %%
ckmktwf.print_table_schema(db_path, print_schema=True)
# Out:
# ...
# Table: Contact
# ...
#
# Columns:
# Name                           Type            NotNull    Default         PK
# --------------------------------------------------------------------------------
# hash                           VARCHAR(255)    False                      True
# origin                         VARCHAR(255)    False                      False
# origin_timestamp               TIMESTAMP       False                      False
# first_name                     VARCHAR(100)    False                      False
# last_name                      VARCHAR(100)    False                      False
# email                          VARCHAR(255)    False                      False
# email_timestamp                TIMESTAMP       False                      False
# email_verification             VARCHAR(32)     False                      False
# email_verification_timestamp   TIMESTAMP       False                      False
# ...

# %%
ckmktwf.print_table_schema(db_path, tables=["Contact"])
# Out:
# ...
# Table: Contact
# ...
#
# Row count: 0

# %%
ckmktwf.print_table_stats(db_path)
# Out:
# ...
# Table: Contact
# ...
# Columns (18): ['hash', 'origin', 'origin_timestamp', 'first_name', 'last_name', 'email', 'email_timestamp', 'email_verification', 'email_verification_timestamp', 'linkedin_url', 'job_title', 'company_name', 'company_domain', 'city', 'country', 'enrichment_timestamp', 'type', 'biography']
# Row count: 0
#
# ...
# Table: Campaign_info
# ...
# Columns (9): ['id', 'name', 'type', 'description', 'message', 'start_date', 'end_date', 'num_targets', 'last_update_timestamp']
# Row count: 0
#
# ...
# Table: Campaign_targets
# ...
# Columns (7): ['id', 'campaign_id', 'first_name', 'last_name', 'email_or_linkedin_url', 'send_timestamp', 'status']
# Row count: 0
#
# ...
# Table: sqlite_sequence
# ...
# Columns (2): ['name', 'seq']
# Row count: 0
#
# ...
# Table: LinkedIn
# ...

# %% [markdown]
# ## Get Contact table

# %%
ckmktwf.get_table_count(db_path, "Contact")
# Out:
# INFO  Table 'Contact' has 0 rows
# 0

# %%
contact_df = ckmktwf.get_as_df(db_path, "Contact")
hpandas.head(contact_df)
# Out:
# 'shape=(0, 18)\n\nEmpty DataFrame\nColumns: [hash, origin, origin_timestamp, first_name, last_name, email, email_timestamp, email_verification, email_verification_timestamp, linkedin_url, job_title, company_name, company_domain, city, country, enrichment_timestamp, type, biography]\nIndex: []'

# %% [markdown]
# ## Query

# %%
contact_df["origin"].unique().tolist()
# Out:
# []

# %% [markdown]
# ## Campaign

# %%
campaign_table_df = ckmktwf.get_as_df(db_path, "Campaign_info")

print(hpandas.head(campaign_table_df))
# Out:
# shape=(0, 9)
#
# Empty DataFrame
# Columns: [id, name, type, description, message, start_date, end_date, num_targets, last_update_timestamp]
# Index: []
