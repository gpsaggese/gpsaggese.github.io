# %% [markdown]
# <a name='description'></a>
# # Description
#
# This notebook examines ...

# %%
#!sudo /bin/bash -c "(source /venv/bin/activate; pip install --quiet jupyterlab-vim)"
#!jupyter labextension enable

# %%
# %load_ext autoreload
# %autoreload 2

import logging
import requests
import os

import pandas as pd

# /venv/lib/python3.12/site-packages/gspread_pandas/spread.py:401: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)` .replace("", np.nan)
pd.set_option("future.no_silent_downcasting", True)

import helpers.hdbg as hdbg
import helpers.henv as henv
import helpers.hprint as hprint

# hcache.get_global_cache_info()
# hcache.clear_global_cache("all")

hdbg.init_logger(verbosity=logging.INFO)
_LOG = logging.getLogger(__name__)

_LOG.info("%s", henv.get_system_signature()[0])
hnotebook.config_notebook()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# WARNING: Logger already initialized: skipping
# INFO  # System signature
#   # Container version
#     container_version='2.0.0'
#     changelog_version='2.2.0'
#   # Git info
#     branch_name='CsfyTask7819_Add_blogs'
#     hash='8a422eadc'
#     # Last commits:
#       * 8a422eadc GP Saggese Update                                                            (   7 hours ago) Fri Dec 12 13:27:16 2025  (HEAD -> CsfyTask7819_Add_blogs, origin/CsfyTask7819_Add_blogs)
#       * 3591241a6 GP Saggese Update                                                            (  19 hours ago) Fri Dec 12 02:06:44 2025
#       * dbe1461af GP Saggese Update                                                            (  19 hours ago) Fri Dec 12 01:57:48 2025
#   # Platform info
#     system=Linux
#     node name=3c9d947a8423
#     release=6.10.14-linuxkit
#     version=#1 SMP Tue Apr 15 16:00:54 UTC 2025
#     machine=aarch64
#     processor=aarch64
#   # psutils info
#     cpu count=8
#     cpu freq=None
#     memory=svmem(total=16749285376, available=14503841792, percent=13.4, used=1982558208, free=12674555904, active=2727170048, inactive=901263360, buffers=340664320, cached=1751506944, shared=872448, slab=277606400)
#     disk usage=sdiskusage(total=270233210880, used=154657918976, free=101814677504, percent=60.3)
#   # Docker info
#     has_docker=True
#     docker_version='28.1.1'
#     docker_needs_sudo=False
#     has_privileged_mode=True
#     is_inside_docker=True
#     has_sibling_containers_support=True
#     has_docker_dind_support=True
#   # Packages
#     python: 3.12.3
#     cvxopt: 1.3.2
#     cvxpy: 1.5.3
#     gluonnlp: ?
#     gluonts: ?
#     joblib: 1.4.2
#     mxnet: ?
#     numpy: 2.1.3
#     pandas: 2.2.3
#     pyarrow: 18.0.0
#     scipy: 1.14.1
#     seaborn: 0.13.2
#     sklearn: 1.5.2
#     statsmodels: 0.14.4

# %% [markdown]
# # HunterIO

# %%
import ck_marketing.plugins as ckmktpi

import importlib

importlib.reload(ckmktpi)
# Out:
# <module 'ck_marketing.plugins' from '/app/ck_marketing/plugins/__init__.py'>

# %% [markdown]
# ## Account info

# %%
# os.environ["HUNTER_API_KEY"] = ""

# %%
pprint.pprint(ckmktpi.get_hunterio_account_info())
# Out:
# {'credits': {'available': 50.0, 'used': 0.0},
#  'reset_date': '2026-01-01',
#  'searches': {'available': 50, 'used': 0},
#  'verifications': {'available': 100, 'used': 0}}

# %% [markdown]
# ## API request

# %%
url = f"https://api.hunter.io/v2/domain-search?company=BraunHagey%20Borden%20LLP&limit=1&api_key={os.environ['HUNTER_API_KEY']}"

response = requests.get(url)
response.raise_for_status()
data = response.json()
import pprint

pprint.pprint(data)
# Out:
# {'data': {'accept_all': False,
#           'disposable': False,
#           'domain': 'braunhagey.com',
#           'emails': [{'confidence': 99,
#                       'department': 'finance',
#                       'first_name': 'Ryan',
#                       'last_name': 'Hill',
#                       'linkedin': 'https://www.linkedin.com/in/ryan-hill-mba-9a4aa69',
#                       'phone_number': None,
#                       'position': 'Chief Financial Officer',
#                       'position_raw': 'Head of Finance and Accounting',
#                       'seniority': 'executive',
#                       'sources': [{'domain': 'linkedin.com',
#                                    'extracted_on': '2025-01-11',
#                                    'last_seen_on': '2025-01-11',
#                                    'still_on_page': True,
#                                    'uri': 'https://www.google.com/search?q=site:linkedin.com%20ryan%20hill%20braunhagey'}],
#                       'twitter': None,
#                       'type': 'personal',
#                       'value': 'hill@braunhagey.com',
#                       'verification': {'date': '2025-11-16',
#                                        'status': 'valid'}}],
#           'linked_domains': [],
#           'organization': 'BraunHagey & Borden',
#           'pattern': '{last}',
#           'webmail': False},
#  'meta': {'limit': 1,
#           'offset': 0,
#           'params': {'company': 'BraunHagey Borden LLP',
#                      'department': None,
#                      'domain': None,
#                      'seniority': None,
#                      'type': None},
#           'results': 76}}

# %% [markdown]
# ## Domain search

# %%
company = "BraunHagey Borden LLP"
pprint.pprint(ckmktpi.hunterio_domain_search(company, limit=2))
# Out:
# {'data': {'accept_all': False,
#           'disposable': False,
#           'domain': 'braunhagey.com',
#           'emails': [{'confidence': 99,
#                       'department': 'finance',
#                       'first_name': 'Ryan',
#                       'last_name': 'Hill',
#                       'linkedin': 'https://www.linkedin.com/in/ryan-hill-mba-9a4aa69',
#                       'phone_number': None,
#                       'position': 'Chief Financial Officer',
#                       'position_raw': 'Head of Finance and Accounting',
#                       'seniority': 'executive',
#                       'sources': [{'domain': 'linkedin.com',
#                                    'extracted_on': '2025-01-11',
#                                    'last_seen_on': '2025-01-11',
#                                    'still_on_page': True,
#                                    'uri': 'https://www.google.com/search?q=site:linkedin.com%20ryan%20hill%20braunhagey'}],
#                       'twitter': None,
#                       'type': 'personal',
#                       'value': 'hill@braunhagey.com',
#                       'verification': {'date': '2025-11-16',
#                                        'status': 'valid'}},
#                      {'confidence': 98,
#                       'department': 'executive',
#                       'first_name': 'Christman',
#                       'last_name': 'Rice',
#                       'linkedin': 'https://www.linkedin.com/in/christman-rice-1b7ab6134',
#                       'phone_number': None,
#                       'position': 'Partner',
#                       'position_raw': 'Partner',
#                       'seniority': None,
#                       'sources': [{'domain': 'braunhagey.squarespace.com',
#                                    'extracted_on': '2023-11-01',
#                                    'last_seen_on': '2025-12-09',
#                                    'still_on_page': True,
#                                    'uri': 'https://braunhagey.squarespace.com/christman-rice'},
#                                   {'domain': 'braunhagey.squarespace.com',
#                                    'extracted_on': '2024-07-31',
#                                    'last_seen_on': '2025-12-09',
#                                    'still_on_page': True,
#                                    'uri': 'https://braunhagey.squarespace.com/contact'},
#                                   {'domain': 'linkedin.com',
#                                    'extracted_on': '2025-01-10',
#                                    'last_seen_on': '2025-11-30',
#                                    'still_on_page': True,
#                                    'uri': 'https://www.google.com/search?q=site:linkedin.com%20christman%20rice%20braunhagey'},
#                                   {'domain': 'braunhagey.com',
#                                    'extracted_on': '2023-10-18',
#                                    'last_seen_on': '2025-11-02',
#                                    'still_on_page': True,
#                                    'uri': 'https://braunhagey.com/christman-rice'},
#                                   {'domain': 'braunhagey.com',
#                                    'extracted_on': '2024-06-25',
#                                    'last_seen_on': '2025-10-24',
#                                    'still_on_page': True,
#                                    'uri': 'https://braunhagey.com/contact'},
#                                   {'domain': 'braunhagey.com',
#                                    'extracted_on': '2024-09-18',
#                                    'last_seen_on': '2024-09-18',
#                                    'still_on_page': True,
#                                    'uri': 'https://braunhagey.com/litigation'},
#                                   {'domain': 'braunhagey.com',
#                                    'extracted_on': '2022-07-15',
#                                    'last_seen_on': '2023-07-18',
#                                    'still_on_page': False,
#                                    'uri': 'https://braunhagey.com/chris-rice'},
#                                   {'domain': 'braunhagey.squarespace.com',
#                                    'extracted_on': '2021-06-12',
#                                    'last_seen_on': '2023-06-29',
#                                    'still_on_page': False,
#                                    'uri': 'https://braunhagey.squarespace.com/chris-rice'}],
#                       'twitter': None,
#                       'type': 'personal',
#                       'value': 'rice@braunhagey.com',
#                       'verification': {'date': '2025-12-04',
#                                        'status': 'valid'}}],
#           'linked_domains': [],
#           'organization': 'BraunHagey & Borden',
#           'pattern': '{last}',
#           'webmail': False},
#  'meta': {'limit': 2,
#           'offset': 0,
#           'params': {'company': 'BraunHagey Borden LLP',
#                      'department': None,
#                      'domain': None,
#                      'seniority': None,
#                      'type': None},
#           'results': 76}}

# %% [markdown]
# ## Email search

# %%
first_name = "Lauren"
last_name = "Chase"
company = "BraunHagey Borden LLP"
pprint.pprint(ckmktpi.hunterio_email_finder(first_name, last_name, company))
# Out:
# {'data': {'accept_all': False,
#           'company': 'BraunHagey & Borden',
#           'domain': 'braunhagey.com',
#           'email': 'chase@braunhagey.com',
#           'first_name': 'Lauren',
#           'last_name': 'Chase',
#           'linkedin_url': None,
#           'phone_number': None,
#           'position': None,
#           'score': 99,
#           'sources': [],
#           'twitter': None,
#           'verification': {'date': '2025-12-12', 'status': 'valid'}},
#  'meta': {'params': {'company': 'BraunHagey Borden LLP',
#                      'domain': None,
#                      'first_name': 'Lauren',
#                      'full_name': None,
#                      'last_name': 'Chase',
#                      'linkedin_handle': None,
#                      'max_duration': None}}}

# %%
first_name = "Lauren"
last_name = "Chase"
company = "BraunHagey Borden LLP"
email = ckmktpi.find_email_intrinsic(
    first_name,
    last_name,
    company,
    is_company=True,
)
print(email)
# Out:
# chase@braunhagey.com

# %%
domain = "upenn.edu"
email = ckmktpi.find_email_intrinsic(
    first_name,
    last_name,
    domain,
    is_company=False,
)
print(email)
# Out:
# WARNING Email not found for 'Lauren' 'Chase' at 'upenn.edu'
# _nan_
