# %% [markdown]
# # Imports

# %%
# if False:
#     !sudo /bin/bash -c "(source /venv/bin/activate; pip install --quiet jupyterlab-vim)"
#     !jupyter labextension enable
#     !sudo /bin/bash -c "(source /venv/bin/activate; pip install --quiet --upgrade google-api-python-client)"

# %%
# !cd /app

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import helpers.hgoogle_drive_api as hgodrapi

hgodrapi.install_needed_modules()
# Out:
# Module 'google' is already installed.
# Module 'googleapiclient' is already installed.
# Module 'gspread' is already installed.

# %%
import logging

import pandas as pd

# /venv/lib/python3.12/site-packages/gspread_pandas/spread.py:401: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)` .replace("", np.nan)
pd.set_option("future.no_silent_downcasting", True)

import helpers.hdbg as hdbg
import helpers.henv as henv
import helpers.hpandas as hpandas
import helpers.hprint as hprint

#
hdbg.init_logger(verbosity=logging.INFO)
_LOG = logging.getLogger(__name__)

#
_LOG.info("%s", henv.get_system_signature()[0])
hnotebook.config_notebook()
# Out:
# WARNING: Logger already initialized: skipping
# INFO  # System signature
#   # Container version
#     container_version='2.0.0'
#     changelog_version='2.2.0'
#   # Git info
#     branch_name='CsfyTask7819_Add_blogs'
#     hash='dde080aaa8'
#     # Last commits:
#       * dde080aaa8 GP Saggese Update                                                            (13 minutes ago) Wed Dec 24 16:22:33 2025  (HEAD -> CsfyTask7819_Add_blogs, origin/CsfyTask7819_Add_blogs)
#       * aad6f8da37 GP Saggese Lint                                                              (  14 hours ago) Wed Dec 24 02:57:50 2025
#       * 5fcf352882 GP Saggese Update                                                            (  14 hours ago) Wed Dec 24 02:55:48 2025
#   # Platform info
#     system=Linux
#     node name=d89e94de37c3
#     release=6.10.14-linuxkit
#     version=#1 SMP Tue Apr 15 16:00:54 UTC 2025
#     machine=aarch64
#     processor=aarch64
#   # psutils info
#     cpu count=8
#     cpu freq=None
#     memory=svmem(total=16749285376, available=13303070720, percent=20.6, used=3183316992, free=11736768512, active=3834527744, inactive=743870464, buffers=264781824, cached=1564418048, shared=888832, slab=267345920)
#     disk usage=sdiskusage(total=270233210880, used=154683105280, free=101789491200, percent=60.3)
#   # Docker info
#     has_docker=True
#     docker_version='28.1.1'
#     docker_needs_sudo=False
#     has_privileged_mode=True
#     is_inside_docker=True
#     has_sibling_containers_support=True
#     has_docker_dind_support=True
#   # Packages
#     python: 3.12.3
#     cvxopt: 1.3.2
#     cvxpy: 1.5.3
#     gluonnlp: ?
#     gluonts: ?
#     joblib: 1.4.2
#     mxnet: ?
#     numpy: 2.1.3
#     pandas: 2.2.3
#     pyarrow: 18.0.0
#     scipy: 1.14.1
#     seaborn: 0.13.2
#     sklearn: 1.5.2
#     statsmodels: 0.14.4

# %%
import gspread
import gspread_pandas

# gspread_pandas.conf.get_config()
print(gspread_pandas.conf.get_config()["project_id"])
print(gspread.__version__)
print(gspread_pandas.__version__)

import helpers.hgoogle_drive_api as hgodrapi

# Get credentials first.
credentials = hgodrapi.get_credentials(
    service_key_path="/home/.config/gspread_pandas/google_secret.json"
)

import ck_marketing.workflows as ckmktwf
import ck_marketing.plugins as ckmktpi

import importlib

importlib.reload(ckmktwf)
importlib.reload(ckmktpi)
# Out:
# gspread-gp
# 5.12.4
# 3.3.0
# <module 'ck_marketing.plugins' from '/app/ck_marketing/plugins/__init__.py'>

# %% [markdown]
# # Load Contact data

# %%
contact_dfs = []

# %% [markdown]
# ## Search4.FinTech_VC_in_US.SalesNavigator

# %%
normalize = True
df_tmp = ckmktwf.get_data_from_PB_SalesNavigator_Connections_Export(normalize)
contact_dfs.append(df_tmp)

# %%
ckmktwf.print_contact_df_stats(df_tmp)
# Out:
#   hash                    origin          origin_timestamp first_name last_name                    email email_timestamp email_verification email_verification_timestamp                                     linkedin_url job_title    company_name company_domain city country enrichment_timestamp type                                          biography
# 0       Search4.FinTech_VC_in_US  2023-11-09T20:34:20.691Z       Adam      Alfi  aalfi@iconiqcapital.com                                                                  https://www.linkedin.com/in/adam-alfi-52891823/   Partner  ICONIQ Capital                                                        Partner at ICONIQ / Growth Stage Technology In...
#                                             0
# num_rows                                  869
# count_no_dups              867 / 869 = 99.77%
# count_no_ascii            867 / 867 = 100.00%
# count_email                465 / 867 = 53.63%
# count_email_verification      0 / 867 = 0.00%
# count_name_dups               0 / 867 = 0.00%
# count_origin              867 / 867 = 100.00%

# %%
print(df_tmp.iloc[0])
# Out:
# hash
# origin                                                   Search4.FinTech_VC_in_US
# origin_timestamp                                         2023-11-09T20:34:20.691Z
# first_name                                                                   Adam
# last_name                                                                    Alfi
# email                                                     aalfi@iconiqcapital.com
# email_timestamp
# email_verification
# email_verification_timestamp
# linkedin_url                      https://www.linkedin.com/in/adam-alfi-52891823/
# job_title                                                                 Partner
# company_name                                                       ICONIQ Capital
# company_domain
# city
# country
# enrichment_timestamp
# type
# biography                       Partner at ICONIQ / Growth Stage Technology In...
# Name: 0, dtype: object

# %% [markdown]
# ## VC_search_export

# %%
normalize = True
df_tmp = ckmktwf.get_data_from_LinkedIn2(normalize)
contact_dfs.append(df_tmp)
# Out:
#   0%|          | 0/11 [00:00<?, ?it/s]

# %%
ckmktwf.print_contact_df_stats(df_tmp)
# Out:
#   hash            origin          origin_timestamp first_name last_name               email email_timestamp email_verification email_verification_timestamp                                       linkedin_url job_title company_name company_domain                                  city country enrichment_timestamp type                                          biography
# 0       VC_search_export  2024-07-11T18:03:01.973Z     Zhenya   Loginov  zloginov@accel.com                            _valid_                               https://www.linkedin.com/in/ACwAAABGC0cBTaYzMW...   Partner        Accel                 Palo Alto, California, United States                                    I invest and help European and Israeli founder...
#                                             0
# num_rows                                  335
# count_no_dups              287 / 335 = 85.67%
# count_no_ascii             285 / 287 = 99.30%
# count_email               285 / 285 = 100.00%
# count_email_verification      0 / 285 = 0.00%
# count_name_dups               2 / 285 = 0.70%
# count_origin              285 / 285 = 100.00%

# %%
# ckmktwf.print_contact_df_detailed_stats(df_tmp)

# %% [markdown]
# ## Search7.AI_VC_in_US.gsheet

# %%
normalize = True
# normalize = False
df_tmp = ckmktwf.get_data_from_LinkedIn3(normalize)
contact_dfs.append(df_tmp)

# %%
ckmktwf.print_contact_df_stats(df_tmp)
# Out:
#   hash               origin origin_timestamp first_name last_name           email email_timestamp email_verification email_verification_timestamp                           linkedin_url job_title      company_name company_domain city country enrichment_timestamp type biography
# 0       Search7.AI_VC_in_US                         Rob     Toews  rob@radical.vc                            _valid_                               https://www.linkedin.com/in/robtoews/            Radical Ventures
#                                             0
# num_rows                                  197
# count_no_dups             197 / 197 = 100.00%
# count_no_ascii            197 / 197 = 100.00%
# count_email               197 / 197 = 100.00%
# count_email_verification      0 / 197 = 0.00%
# count_name_dups               0 / 197 = 0.00%
# count_origin              197 / 197 = 100.00%

# %% [markdown]
# ## VC Tier 1 - Partners

# %%
normalize = True
df_tmp = ckmktwf.get_data_from_VCSheet(normalize)
contact_dfs.append(df_tmp)

# %%
ckmktwf.print_contact_df_stats(df_tmp)
# Out:
#   hash          origin origin_timestamp first_name last_name              email email_timestamp email_verification email_verification_timestamp                         linkedin_url                      job_title company_name company_domain city country enrichment_timestamp type biography
# 0       VCSheet_Query1                         Ann  Miura-Ko  ann@floodgate.com                                                                  https://www.linkedin.com/in/amiura/  Co-Founding Partner@Floodgate    Floodgate
#                                             0
# num_rows                                  964
# count_no_dups             964 / 964 = 100.00%
# count_no_ascii             962 / 964 = 99.79%
# count_email                890 / 962 = 92.52%
# count_email_verification      0 / 962 = 0.00%
# count_name_dups               1 / 962 = 0.10%
# count_origin              962 / 962 = 100.00%

# %% [markdown]
# ## VC_Tier_2_Partners

# %%
normalize = True
df_tmp = ckmktwf.get_data_from_LinkedIn5(normalize)
contact_dfs.append(df_tmp)

# %%
ckmktwf.print_contact_df_stats(df_tmp)
# Out:
#   hash     origin origin_timestamp first_name last_name                       email email_timestamp email_verification email_verification_timestamp linkedin_url job_title   company_name    company_domain                               city country enrichment_timestamp type biography
# 0       VC Tier 2                   Rodriguez      Keig  rodriguez@foundersfund.com                          _invalid_                                             Founder  Founders Fund  foundersfund.com  New York, New York, United States
#                                             0
# num_rows                                  253
# count_no_dups              251 / 253 = 99.21%
# count_no_ascii            251 / 251 = 100.00%
# count_email               251 / 251 = 100.00%
# count_email_verification      0 / 251 = 0.00%
# count_name_dups               0 / 251 = 0.00%
# count_origin              251 / 251 = 100.00%

# %% [markdown]
# ## VCSheet

# %%
normalize = True
# normalize = False
df_tmp = ckmktwf.get_data_from_VCSheet(normalize)
contact_dfs.append(df_tmp)

# %%
ckmktwf.print_contact_df_stats(df_tmp)
# Out:
#   hash          origin origin_timestamp first_name last_name              email email_timestamp email_verification email_verification_timestamp                         linkedin_url                      job_title company_name company_domain city country enrichment_timestamp type biography
# 0       VCSheet_Query1                         Ann  Miura-Ko  ann@floodgate.com                                                                  https://www.linkedin.com/in/amiura/  Co-Founding Partner@Floodgate    Floodgate
#                                             0
# num_rows                                  964
# count_no_dups             964 / 964 = 100.00%
# count_no_ascii             962 / 964 = 99.79%
# count_email                890 / 962 = 92.52%
# count_email_verification      0 / 962 = 0.00%
# count_name_dups               1 / 962 = 0.10%
# count_origin              962 / 962 = 100.00%

# %% [markdown]
# ## Euro-VCs

# %%
normalize = True
# normalize = False
df_tmp = ckmktwf.get_data_from_EuroVC(normalize)
contact_dfs.append(df_tmp)

# %%
ckmktwf.print_contact_df_stats(df_tmp)
# Out:
#   hash            origin          origin_timestamp first_name last_name email email_timestamp email_verification email_verification_timestamp                                 linkedin_url                 job_title                           company_name company_domain  city country enrichment_timestamp type biography
# 1       Euro-VC-LinkedIn  2020-08-20T16:15:48.000Z     Julian  Zachmann                                                                        https://www.linkedin.com/in/julianzachmann/  Venture Capital Investor  http://www.high-tech-gruenderfonds.de                 Bonn
#                                             0
# num_rows                                  557
# count_no_dups              556 / 557 = 99.82%
# count_no_ascii            556 / 556 = 100.00%
# count_email                159 / 556 = 28.60%
# count_email_verification      0 / 556 = 0.00%
# count_name_dups               2 / 556 = 0.36%
# count_origin              556 / 556 = 100.00%

# %% [markdown]
# ## Folkapp

# %%
normalize = True
# normalize = False
df_tmp = ckmktwf.get_data_from_FolkApp(normalize)
contact_dfs.append(df_tmp)

# %%
ckmktwf.print_contact_df_stats(df_tmp)
# Out:
#   hash   origin origin_timestamp first_name  last_name                     email email_timestamp email_verification email_verification_timestamp                                linkedin_url                                       job_title     company_name company_domain       city country enrichment_timestamp type biography
# 0       Folkapp                       Susan  Akbarpour  susan@candouventures.com                                                                  https://www.linkedin.com/in/susanakbarpour  Investor, Serial entrepreneur and board member  Candou Ventures                 Palo Alto
#                                               0
# num_rows                                   2216
# count_no_dups             2216 / 2216 = 100.00%
# count_no_ascii             2213 / 2216 = 99.86%
# count_email                2211 / 2213 = 99.91%
# count_email_verification       0 / 2213 = 0.00%
# count_name_dups                9 / 2213 = 0.41%
# count_origin              2213 / 2213 = 100.00%

# %% [markdown]
# # Concat all

# %%
contact_df = pd.concat(contact_dfs)
debug = ""
# debug = "duplicated_emails"
# debug = "remove_chinese_names"
# debug = "remove_empty_first_name"
# debug = "clean_company_names"
# debug = "clean_linkedin_emails"
# debug = "clean_linkedin_websites"
contact_df = ckmktwf.clean_up_contact_df(contact_df, debug=debug)
display(contact_df.head(2))
# Out:
#                                              0
# duplicated_emails         1234 / 6355 = 19.42%
# remove_invalid_emails        10 / 5121 = 0.20%
# remove_chinese_names          0 / 5111 = 0.00%
# remove_empty_first_names      1 / 5111 = 0.02%
# clean_company_names        539 / 5110 = 10.55%
# clean_linkedin_nans           0 / 5110 = 0.00%
# clean_linkedin_emails         1 / 5110 = 0.02%
# clean_linkedin_websites       2 / 5110 = 0.04%
# clean_emails                  0 / 5110 = 0.00%
#                                hash                    origin          origin_timestamp first_name last_name                    email email_timestamp email_verification email_verification_timestamp                                     linkedin_url                              job_title    company_name company_domain city country enrichment_timestamp type                                          biography
# 0  ac52f900bfbdcf07070a1deb04ceaba4  Search4.FinTech_VC_in_US  2023-11-09T20:34:20.691Z       Adam      Alfi  aalfi@iconiqcapital.com                                                                  https://www.linkedin.com/in/adam-alfi-52891823/                                Partner  ICONIQ Capital                                                        Partner at ICONIQ / Growth Stage Technology In...
# 1  252520bb30bc09f55e92fdbfb6cf09e9  Search4.FinTech_VC_in_US  2023-11-10T05:33:23.329Z      Amman    Bhasin       abhasin@paypal.com                                                                         https://www.linkedin.com/in/ammanbhasin/  Investment Partner at PayPal Ventures          PayPal                                                        I'm excited by the rapid pace that technology ...

# %%
contact_df.iloc[0]
# Out:
# hash                                             ac52f900bfbdcf07070a1deb04ceaba4
# origin                                                   Search4.FinTech_VC_in_US
# origin_timestamp                                         2023-11-09T20:34:20.691Z
# first_name                                                                   Adam
# last_name                                                                    Alfi
# email                                                     aalfi@iconiqcapital.com
# email_timestamp
# email_verification
# email_verification_timestamp
# linkedin_url                      https://www.linkedin.com/in/adam-alfi-52891823/
# job_title                                                                 Partner
# company_name                                                       ICONIQ Capital
# company_domain
# city
# country
# enrichment_timestamp
# type
# biography                       Partner at ICONIQ / Growth Stage Technology In...
# Name: 0, dtype: object

# %%
ckmktwf.print_contact_df_detailed_stats(contact_df)
# Out:
# <style type="text/css">
# #T_192b2_row0_col0, #T_192b2_row1_col0, #T_192b2_row3_col0, #T_192b2_row4_col0, #T_192b2_row6_col2, #T_192b2_row6_col3, #T_192b2_row8_col2, #T_192b2_row8_col3, #T_192b2_row14_col2, #T_192b2_row14_col3, #T_192b2_row15_col2, #T_192b2_row15_col3, #T_192b2_row16_col2, #T_192b2_row16_col3 {
#   background-color: #4479bb;
#   color: #f1f1f1;
# }
# #T_192b2_row0_col1 {
#   background-color: #4c7ebd;
#   color: #f1f1f1;
# }
# #T_192b2_row0_col2, #T_192b2_row0_col3, #T_192b2_row0_col4, #T_192b2_row1_col1, #T_192b2_row1_col2, #T_192b2_row1_col3, #T_192b2_row1_col4, #T_192b2_row2_col4, #T_192b2_row3_col2, #T_192b2_row3_col3, #T_192b2_row3_col4, #T_192b2_row4_col2, #T_192b2_row4_col3, #T_192b2_row4_col4, #T_192b2_row5_col4, #T_192b2_row6_col0, #T_192b2_row6_col1, #T_192b2_row6_col4, #T_192b2_row7_col1, #T_192b2_row7_col4, #T_192b2_row8_col0, #T_192b2_row8_col1, #T_192b2_row8_col4, #T_192b2_row9_col4, #T_192b2_row10_col4, #T_192b2_row11_col4, #T_192b2_row12_col4, #T_192b2_row13_col4, #T_192b2_row14_col0, #T_192b2_row14_col1, #T_192b2_row14_col4, #T_192b2_row15_col0, #T_192b2_row15_col1, #T_192b2_row15_col4, #T_192b2_row16_col0, #T_192b2_row16_col1, #T_192b2_row16_col4, #T_192b2_row17_col4 {
#   background-color: #d73c5b;
#   color: #f1f1f1;
# }
# #T_192b2_row2_col0 {
#   background-color: #e9afbb;
#   color: #000000;
# }
# #T_192b2_row2_col1 {
#   background-color: #e17a8f;
#   color: #f1f1f1;
# }
# #T_192b2_row2_col2, #T_192b2_row2_col3 {
#   background-color: #b2c6de;
#   color: #000000;
# }
# #T_192b2_row3_col1 {
#   background-color: #edcdd3;
#   color: #000000;
# }
# #T_192b2_row4_col1 {
#   background-color: #98b3d6;
#   color: #000000;
# }
# #T_192b2_row5_col0, #T_192b2_row5_col1 {
#   background-color: #84a5cf;
#   color: #f1f1f1;
# }
# #T_192b2_row5_col2, #T_192b2_row5_col3 {
#   background-color: #e17e92;
#   color: #f1f1f1;
# }
# #T_192b2_row7_col0, #T_192b2_row11_col2, #T_192b2_row11_col3 {
#   background-color: #de687f;
#   color: #f1f1f1;
# }
# #T_192b2_row7_col2, #T_192b2_row7_col3, #T_192b2_row11_col0 {
#   background-color: #6e96c8;
#   color: #f1f1f1;
# }
# #T_192b2_row9_col0 {
#   background-color: #e4e9ee;
#   color: #000000;
# }
# #T_192b2_row9_col1 {
#   background-color: #ebedf1;
#   color: #000000;
# }
# #T_192b2_row9_col2, #T_192b2_row9_col3 {
#   background-color: #f0e4e6;
#   color: #000000;
# }
# #T_192b2_row10_col0 {
#   background-color: #e7eaef;
#   color: #000000;
# }
# #T_192b2_row10_col1 {
#   background-color: #e595a5;
#   color: #000000;
# }
# #T_192b2_row10_col2, #T_192b2_row10_col3 {
#   background-color: #f1e7e9;
#   color: #000000;
# }
# #T_192b2_row11_col1 {
#   background-color: #d5deea;
#   color: #000000;
# }
# #T_192b2_row12_col0 {
#   background-color: #dfe5ed;
#   color: #000000;
# }
# #T_192b2_row12_col1 {
#   background-color: #f2eded;
#   color: #000000;
# }
# #T_192b2_row12_col2, #T_192b2_row12_col3 {
#   background-color: #f0dee2;
#   color: #000000;
# }
# #T_192b2_row13_col0 {
#   background-color: #a3bbd9;
#   color: #000000;
# }
# #T_192b2_row13_col1 {
#   background-color: #e0778c;
#   color: #f1f1f1;
# }
# #T_192b2_row13_col2, #T_192b2_row13_col3 {
#   background-color: #e6a0ae;
#   color: #000000;
# }
# #T_192b2_row17_col0, #T_192b2_row17_col1 {
#   background-color: #e0748a;
#   color: #f1f1f1;
# }
# #T_192b2_row17_col2, #T_192b2_row17_col3 {
#   background-color: #7a9fcc;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_192b2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_192b2_level0_col0" class="col_heading level0 col0" >valid [pct]</th>
#       <th id="T_192b2_level0_col1" class="col_heading level0 col1" >unique [pct]</th>
#       <th id="T_192b2_level0_col2" class="col_heading level0 col2" >invalid [pct]</th>
#       <th id="T_192b2_level0_col3" class="col_heading level0 col3" >empty [pct]</th>
#       <th id="T_192b2_level0_col4" class="col_heading level0 col4" >nan [pct]</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >col_name</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_192b2_level0_row0" class="row_heading level0 row0" >hash</th>
#       <td id="T_192b2_row0_col0" class="data row0 col0" >100.000000</td>
#       <td id="T_192b2_row0_col1" class="data row0 col1" >97.590000</td>
#       <td id="T_192b2_row0_col2" class="data row0 col2" >0.000000</td>
#       <td id="T_192b2_row0_col3" class="data row0 col3" >0.000000</td>
#       <td id="T_192b2_row0_col4" class="data row0 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_192b2_level0_row1" class="row_heading level0 row1" >origin</th>
#       <td id="T_192b2_row1_col0" class="data row1 col0" >100.000000</td>
#       <td id="T_192b2_row1_col1" class="data row1 col1" >0.140000</td>
#       <td id="T_192b2_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_192b2_row1_col3" class="data row1 col3" >0.000000</td>
#       <td id="T_192b2_row1_col4" class="data row1 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_192b2_level0_row2" class="row_heading level0 row2" >origin_timestamp</th>
#       <td id="T_192b2_row2_col0" class="data row2 col0" >31.960000</td>
#       <td id="T_192b2_row2_col1" class="data row2 col1" >17.380000</td>
#       <td id="T_192b2_row2_col2" class="data row2 col2" >68.040000</td>
#       <td id="T_192b2_row2_col3" class="data row2 col3" >68.040000</td>
#       <td id="T_192b2_row2_col4" class="data row2 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_192b2_level0_row3" class="row_heading level0 row3" >first_name</th>
#       <td id="T_192b2_row3_col0" class="data row3 col0" >100.000000</td>
#       <td id="T_192b2_row3_col1" class="data row3 col1" >39.940000</td>
#       <td id="T_192b2_row3_col2" class="data row3 col2" >0.000000</td>
#       <td id="T_192b2_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_192b2_row3_col4" class="data row3 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_192b2_level0_row4" class="row_heading level0 row4" >last_name</th>
#       <td id="T_192b2_row4_col0" class="data row4 col0" >99.920000</td>
#       <td id="T_192b2_row4_col1" class="data row4 col1" >75.710000</td>
#       <td id="T_192b2_row4_col2" class="data row4 col2" >0.080000</td>
#       <td id="T_192b2_row4_col3" class="data row4 col3" >0.080000</td>
#       <td id="T_192b2_row4_col4" class="data row4 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_192b2_level0_row5" class="row_heading level0 row5" >email</th>
#       <td id="T_192b2_row5_col0" class="data row5 col0" >81.490000</td>
#       <td id="T_192b2_row5_col1" class="data row5 col1" >81.510000</td>
#       <td id="T_192b2_row5_col2" class="data row5 col2" >18.510000</td>
#       <td id="T_192b2_row5_col3" class="data row5 col3" >18.510000</td>
#       <td id="T_192b2_row5_col4" class="data row5 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_192b2_level0_row6" class="row_heading level0 row6" >email_timestamp</th>
#       <td id="T_192b2_row6_col0" class="data row6 col0" >0.000000</td>
#       <td id="T_192b2_row6_col1" class="data row6 col1" >0.020000</td>
#       <td id="T_192b2_row6_col2" class="data row6 col2" >100.000000</td>
#       <td id="T_192b2_row6_col3" class="data row6 col3" >100.000000</td>
#       <td id="T_192b2_row6_col4" class="data row6 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_192b2_level0_row7" class="row_heading level0 row7" >email_verification</th>
#       <td id="T_192b2_row7_col0" class="data row7 col0" >12.330000</td>
#       <td id="T_192b2_row7_col1" class="data row7 col1" >0.100000</td>
#       <td id="T_192b2_row7_col2" class="data row7 col2" >87.670000</td>
#       <td id="T_192b2_row7_col3" class="data row7 col3" >87.670000</td>
#       <td id="T_192b2_row7_col4" class="data row7 col4" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_192b2_level0_row8" class="row_heading level0 row8" >email_verification_timestamp</th>
#       <td id="T_192b2_row8_col0" class="data row8 col0" >0.000000</td>
#       <td id="T_192b2_row8_col1" class="data row8 col1" >0.020000</td>
#       <td i

# %%
ckmktwf.sanity_check_contact_df(contact_df)
# Out:
# {'nan': 0.5246575342465754, 'match': 0.3913894324853229, 'mismatch': 0.08395303326810176}

# %%
ckmktwf.print_contact_df_stats(contact_df)
# Out:
#                                hash                    origin          origin_timestamp first_name last_name                    email email_timestamp email_verification email_verification_timestamp                                     linkedin_url job_title    company_name company_domain city country enrichment_timestamp type                                          biography
# 0  ac52f900bfbdcf07070a1deb04ceaba4  Search4.FinTech_VC_in_US  2023-11-09T20:34:20.691Z       Adam      Alfi  aalfi@iconiqcapital.com                                                                  https://www.linkedin.com/in/adam-alfi-52891823/   Partner  ICONIQ Capital                                                        Partner at ICONIQ / Growth Stage Technology In...
#                                               0
# num_rows                                   5110
# count_no_dups              5033 / 5110 = 98.49%
# count_no_ascii             5028 / 5033 = 99.90%
# count_email                4159 / 5028 = 82.72%
# count_email_verification       0 / 5028 = 0.00%
# count_name_dups              187 / 5028 = 3.72%
# count_origin              5028 / 5028 = 100.00%

# %%
display(contact_df["origin"].value_counts().to_frame())
# Out:
#                           count
# origin
# Folkapp                    2076
# VCSheet_Query1              986
# Search4.FinTech_VC_in_US    868
# Euro-VC-LinkedIn            549
# VC Tier 2                   229
# VC_search_export            216
# Search7.AI_VC_in_US         186

# %%
# ckmktwf.save_to_gsheet(contact_df)

# %% [markdown]
# # Process Contact data

# %% [markdown]
# ## Clean up names

# %%
contact_df = ckmktpi.clean_and_track_name_changes(contact_df)

debug_df = ckmktpi.get_debug_clean_name_df(contact_df)
ckmktpi.get_clean_name_stats(contact_df)
# Out:
#   first_name last_name cleaned_first_name first_alias cleaned_last_name second_alias  is_modified
# 0       Adam      Alfi               Adam                          Alfi                     False
# 1      Amman    Bhasin              Amman                        Bhasin                     False
# 2       Andy   Canales               Andy                       Canales                     False
#                                    0
# is_modified       238 / 5110 = 4.66%
# empty_first_name    4 / 5110 = 0.08%
# empty_last_name     6 / 5110 = 0.12%
# has_alias          21 / 5110 = 0.41%

# %%
hpandas.filter_df(debug_df, "is_modified", True).head(2)
# Out:
# INFO  selected=238 / 5110 = 4.66%
#    first_name                 last_name cleaned_first_name first_alias  cleaned_last_name second_alias  is_modified
# 8     Alexsis         de Raadt St James            Alexsis              De Raadt St James                      True
# 10   Adrianna  Samaniego (she/her/ella)           Adrianna                      Samaniego                      True

# %%
contact_df = ckmktpi.merge_clean_names_df(contact_df)

contact_df.head(1)
# Out:
#                                hash                    origin          origin_timestamp first_name last_name                    email email_timestamp email_verification email_verification_timestamp                                     linkedin_url job_title    company_name company_domain city country enrichment_timestamp type                                          biography
# 0  ac52f900bfbdcf07070a1deb04ceaba4  Search4.FinTech_VC_in_US  2023-11-09T20:34:20.691Z       Adam      Alfi  aalfi@iconiqcapital.com                                                                  https://www.linkedin.com/in/adam-alfi-52891823/   Partner  ICONIQ Capital                                                        Partner at ICONIQ / Growth Stage Technology In...

# %%
# ckmktwf.save_to_gsheet(df)

# %% [markdown]
# # Load into DB

# %%
db_path = "test.sql"

# %%
# mode = "assume_no_overlap"
# mode = "assume_idempotent"
mode = "keep_new"
log_level = logging.DEBUG
df_out = ckmktwf.insert_contact_df(
    db_path, contact_df, mode, log_level=log_level
)
# Out:
# Inserting rows: 100%|██████████████████████████████████████████████████████████████████████████| 5110/5110 [00:00<00:00, 245292.16it/s]

# %%
ckmktwf.print_contact_stats(db_path)
# Out:
# Contact contact shape: (5186, 18)
# Contact head:
#                                hash                                         origin          origin_timestamp first_name last_name email email_timestamp email_verification email_verification_timestamp                        linkedin_url                            job_title company_name company_domain                               city country enrichment_timestamp type                                          biography
# 0  8ae2fdf3ad9273ef1bad903f58feb87c  PB.LIN_Profile_Scraper.MA_targets_10k_persons  2025-12-24T00:29:39.324Z      Fawaz     Ahmar                                                                        https://linkedin.com/in/fawazahmar  Senior Director - FS / M&A Advisory          PwC                 New York, New York, United States                                    Senior Director | FS / M&A Advisory | PwC; Faw...
#                                                count
# origin
# Folkapp                                         2068
# VCSheet_Query1                                   913
# Search4.FinTech_VC_in_US                         842
# Euro-VC-LinkedIn                                 547
# VC Tier 2                                        223
# VC_search_export                                 216
# PB.LIN_Profile_Scraper.MA_targets_10k_persons    199
# Search7.AI_VC_in_US                              178
