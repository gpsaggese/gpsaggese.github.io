# %% [markdown]
# # Imports

# %%
# !sudo /bin/bash -c "(source /venv/bin/activate; pip install --quiet jupyterlab-vim)"
# !jupyter labextension enable

#!sudo /bin/bash -c "(source /venv/bin/activate; pip install --quiet --upgrade google-api-python-client)"

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import logging

import helpers.hdbg as hdbg
import helpers.henv as henv
import helpers.hprint as hprint

hdbg.init_logger(verbosity=logging.INFO)
_LOG = logging.getLogger(__name__)
_LOG.info("%s", henv.get_system_signature()[0])

hnotebook.config_notebook()
# Out:
# WARNING: Running in Jupyter
# INFO  > cmd='/venv/lib/python3.12/site-packages/ipykernel_launcher.py -f /home/.local/share/jupyter/runtime/kernel-8ca75ec3-f172-441e-bfdb-5e7d4dc699fe.json'
#
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (arm64v8)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
# ...

# %%
import pandas as pd

import helpers.hgoogle_drive_api as hgodrapi

# Get credentials.
credentials = hgodrapi.get_credentials(
    service_key_path="/home/.config/gspread_pandas/google_secret.json"
)

# %%
import importlib

import ck_marketing.workflows as ckmktwf

importlib.reload(ckmktwf)
# Out:
# /app/ck_marketing/workflows/data_loaders.py:15: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm
# <module 'ck_marketing.workflows' from '/app/ck_marketing/workflows/__init__.py'>

# %%
db_path = "test.sql"

# %%
ckmktwf.print_table_schema(db_path, print_schema=False)
# Out:
# ...
# Table: Contact_table
# ...
#
# Row count: 4347
#
# ...
# Table: LinkedIn_table
# ...
#
# Row count: 0
#
# ...

# %%
ckmktwf.print_table_schema(db_path, tables=["Contact_table"])
# Out:
# ...
# Table: Contact_table
# ...
#
# Row count: 4347
#
# ...

# %%
ckmktwf.get_contact_count(db_path)
# Out:
# 4347

# %%
contact_df = ckmktwf.get_as_df(db_path, "Contact_table")
hpandas.head(contact_df)
# Out:
# columns= ['hash', 'origin', 'origin_timestamp', 'first_name', 'last_name', 'email', 'email_timestamp', 'email_verification', 'email_verification_timestamp', 'linkedin_url', 'job_title', 'job_title_description', 'company_name', 'company_domain', 'city', 'country', 'enrichment_timestamp', 'type']
# shape= (4347, 18)
#                                hash                       origin            origin_timestamp first_name last_name                     email             email_timestamp email_verification email_verification_timestamp                                    linkedin_url                                          job_title job_title_description                        company_name company_domain       city  country enrichment_timestamp type
# ...

# %% [markdown]
# # Read a Yamm campaign

# %%
urls = [
    (
        "https://docs.google.com/spreadsheets/d/1HyglraD02TJwp16wkU_yZZ6jJW51LnBdlaWsVSTNLws/edit?gid=0#gid=0",
        "Sheet1",
    ),
    (
        "https://docs.google.com/spreadsheets/d/1HyglraD02TJwp16wkU_yZZ6jJW51LnBdlaWsVSTNLws/edit?gid=0#gid=0",
        "Sheet2",
    ),
    # ("https://docs.google.com/spreadsheets/d/1HyglraD02TJwp16wkU_yZZ6jJW51LnBdlaWsVSTNLws/edit?gid=0#gid=0", "2025-12-12"),
]

# Extract the BOUNCED and mark it as "yamm.bounced".
url, tab_name = urls[0]
print(url)
normalize = True

yamm_df = hgodrapi.from_gsheet(url, tab_name=tab_name, credentials=credentials)
# Out:
# https://docs.google.com/spreadsheets/d/1HyglraD02TJwp16wkU_yZZ6jJW51LnBdlaWsVSTNLws/edit?gid=0#gid=0

# %%
contact_df.head(2)
# Out:
#                                hash                       origin            origin_timestamp first_name last_name                     email             email_timestamp email_verification email_verification_timestamp                                    linkedin_url                                          job_title job_title_description                        company_name company_domain       city  country enrichment_timestamp type
# 0  c7aebb80a7bc2167ad058b8f6fae2fc5  Pitchbook.200AICompanies.MA  2025-12-15 16:53:07.146783     Oliver   Steinig  oliver.steinig@bosch.com  2025-12-15 16:53:07.146783                                                  http://linkedin.com/in/oliver-steinig-68603aa/  Vice President of Business Development and Cor...                                        Bosch (Automotive)                 Gerlingen  Germany
# ...

# %%
yamm_df.head(2)
# Out:
#    idx          People                                      LinkedInURL  LastName FirstName PrimaryCompany                                 PrimaryPosition State/Province Country/Territory/Region                         Email                                          EmailText Merge status
# 0  165  David Schmaier  http://linkedin.com/in/david-schmaier-70476b43/  Schmaier     David     Salesforce              President & Chief Strategy Officer     California            United States  davidschmaier@salesforce.com  Hi David,\n\nI’m GP Saggese, CTO of Causify.AI...   EMAIL_SENT
# 1  512   Assaf Feldman   http://il.linkedin.com/in/assaf-feldman-991167   Feldman     Assaf      Riskified  Chief Technology Officer, Technology & Founder                                  Israel           assaf@riskified.com  Hi Assaf,\n\nI’m GP Saggese, CTO of Causify.AI...   EMAIL_SENT

# %%
timestamp = pd.Timestamp.now()
out_df = ckmktwf.update_df_with_yamm_bounced(
    contact_df,
    yamm_df,
    timestamp,
    email_col1="email",
    email_col2="Email",
    yamm_col="Merge status",
)
# Out:
# INFO  Updating contact df (4347 rows) with YAMM results (83 rows)
# INFO  Changed state to _yamm_bounced_: 0 -> 25

# %%
out_df
# Out:
#                                   hash                                             origin            origin_timestamp first_name   last_name                          email             email_timestamp email_verification email_verification_timestamp                                       linkedin_url                                          job_title job_title_description                        company_name company_domain           city        country enrichment_timestamp type  yamm.bounced
# 0     c7aebb80a7bc2167ad058b8f6fae2fc5                        Pitchbook.200AICompanies.MA  2025-12-15 16:53:07.146783     Oliver     Steinig       oliver.steinig@bosch.com  2025-12-15 16:53:07.146783                                                     http://linkedin.com/in/oliver-steinig-68603aa/  Vice President of Business Development and Cor...                                        Bosch (Automotive)                     Gerlingen        Germany                                   False
# ...
