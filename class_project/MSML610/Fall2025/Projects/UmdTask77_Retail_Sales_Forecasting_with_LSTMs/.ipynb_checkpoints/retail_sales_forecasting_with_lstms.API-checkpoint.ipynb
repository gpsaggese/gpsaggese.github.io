# %% [markdown]
# # Retail Sales Forecasting API Walkthrough
#
# This notebook demonstrates the core API surface exposed by `retail_sales_forecasting_with_lstms.API`. Each section mirrors the markdown tutorial and uses the synthetic fallback so it runs in any environment.

# %%
from pathlib import Path
import sys

PROJECT_DIR = Path.cwd() / 'class_project/MSML610/Fall2025/Projects/UmdTask77_Retail_Sales_Forecasting_with_LSTMs'
if str(PROJECT_DIR) not in sys.path:
    sys.path.append(str(PROJECT_DIR))

# %%
from pathlib import Path

from retail_sales_forecasting_with_lstms.API import (
    TrainingConfig,
    train_models,
    run_training_pipeline,
    load_run_metrics,
    run_inference,
)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 3
#       1 from pathlib import Path
# ----> 3 from retail_sales_forecasting_with_lstms.API import (
#       4     TrainingConfig,
#       5     train_models,
#       6     run_training_pipeline,
#       7     load_run_metrics,
#       8     run_inference,
#       9 )
#
# File /app/project/class_project/MSML610/Fall2025/Projects/UmdTask77_Retail_Sales_Forecasting_with_LSTMs/retail_sales_forecasting_with_lstms/__init__.py:27
#      25 for _sub in ("API", "example"):
#      26     try:
# ---> 27         _load(_sub)
#      28     except ImportError:
#      29         pass
#
# File /app/project/class_project/MSML610/Fall2025/Projects/UmdTask77_Retail_Sales_Forecasting_with_LSTMs/retail_sales_forecasting_with_lstms/__init__.py:21, in _load(submodule)
#      19 spec = importlib.util.spec_from_loader(qualified, loader)
#      20 module = importlib.util.module_from_spec(spec)
# ---> 21 loader.exec_module(module)
#      22 sys.modules[qualified] = module
#
# File /app/project/class_project/MSML610/Fall2025/Projects/UmdTask77_Retail_Sales_Forecasting_with_LSTMs/retail_sales_forecasting_with_lstms.API.py:10
#       1 """
#       2 Typed API surface for the Retail Sales Forecasting project (JAX).
#       3
#    (...)
#       7 `retail_sales_forecasting_utils.py`.
#       8 """
# ---> 10 from retail_sales_forecasting_utils import (
#      11     DatasetSplits,
#      12     TrainingConfig,
#      13     TrainingResult,
#      14     build_model,
#      15     create_run_directory,
#      16     load_run_config,
#      17     load_run_metrics,
#      18     plot_breakdowns,
#      19     plot_final_metrics_comparison,
#      20     plot_predictions_sample,
#      21     plot_sales_metrics,
#      22     plot_training_curves,
#      23     prepare_dataset,
#      24     run_inference,
#      25     run_training_pipeline,
#      26     save_run_artifacts,
#      27     train_model,
#      28     train_models,
#      29 )
#      31 __all__ = [
#      32     "TrainingConfig",
#      33     "DatasetSplits",
#    (...)
#      49     "plot_predictions_sample",
#      50 ]
#
# File /app/project/class_project/MSML610/Fall2025/Projects/UmdTask77_Retail_Sales_Forecasting_with_LSTMs/retail_sales_forecasting_utils.py:22
#      19 from pathlib import Path
#      20 from typing import Dict, Iterable, List, Mapping, Optional, Sequence, Tuple
# ---> 22 import jax
#      23 import jax.numpy as jnp
#      24 import matplotlib.pyplot as plt
#
# File /usr/local/lib/python3.8/dist-packages/jax/__init__.py:35
#      30 del _cloud_tpu_init
#      32 # Confusingly there are two things named "config": the module and the class.
#      33 # We want the exported object to be the class, so we first import the module
#      34 # to make sure a later import doesn't overwrite the class.
# ---> 35 from jax import config as _config_module
#      36 del _config_module
#      38 # Force early import, allowing use of `jax.core` after importing `jax`.
#
# File /usr/local/lib/python3.8/dist-packages/jax/config.py:17
#       1 # Copyright 2018 The JAX Authors.
#       2 #
#       3 # Licensed under the Apache License, Version 2.0 (the "License");
#    (...)
#      14
#      15 # TODO(phawkins): fix users of this alias and delete this file.
# ---> 17 from jax._src.config import config  # noqa: F401
#
# File /usr/local/lib/python3.8/dist-packages/jax/_src/config.py:24
#      21 import threading
#      22 from typing import Any, List, Callable, Hashable, NamedTuple, Iterator, Optional
# ---> 24 from jax._src import lib
#      25 from jax._src.lib import jax_jit
#      26 from jax._src.lib import transfer_guard_lib
#
# File /usr/local/lib/python3.8/dist-packages/jax/_src/lib/__init__.py:84
#      80 # Before importing any C compiled modules from jaxlib, first import the CPU
#      81 # feature guard module to verify that jaxlib was compiled in a way that only
#      82 # uses instructions that are present on this machine.
#      83 import jaxlib.cpu_feature_guard as cpu_feature_guard
# ---> 84 cpu_feature_guard.check_cpu_features()
#      86 # TODO(phawkins): remove after minimium jaxlib version is 0.4.9 or newer.
#      87 try:
#
# RuntimeError: This version of jaxlib was built using AVX instructions, which your CPU and/or operating system do not support. You may be able work around this issue by building jaxlib from source.

# %% [markdown]
# ## 1. Configure the pipeline
# Use a small subset of stores/families and `synthetic_if_missing=True` so this cell executes quickly.

# %%
cfg_api = TrainingConfig(
    data_dir=Path("data/store-sales-time-series-forecasting"),
    families=("GROCERY I", "BEVERAGES"),
    max_stores=2,
    context_length=12,
    horizon=4,
    epochs=1,
    batch_size=64,
    synthetic_if_missing=True,
)
cfg_api

# %% [markdown]
# ## 2. Train a model in-memory
# `train_models` returns both the `TrainingResult` list and the dataset used for evaluation. This is useful when you do not want to persist artifacts yet.

# %%
results, dataset = train_models(cfg_api, model_names=("lstm",))
results[0].normalized_metrics

# %% [markdown]
# ## 3. Persist a run
# `run_training_pipeline` saves `config.json`, metrics, and the pickled parameters. The run directory is used later inside the documentation and video.

# %%
run_dir, saved_results, dataset = run_training_pipeline(
    cfg_api,
    output_dir=Path("artifacts/api_demo"),
    run_name="api_notebook_demo",
    model_names=("lstm",),
)
run_dir

# %% [markdown]
# ## 4. Reload metrics & run inference
# Loading the saved artifacts is a one-liner, which keeps the video walkthrough deterministic.

# %%
metrics = load_run_metrics(run_dir)
inference = run_inference(run_dir, "lstm", dataset=dataset)
metrics["lstm"]["normalized_metrics"], inference["mse"]
