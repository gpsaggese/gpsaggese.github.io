# %% [markdown]
# # COVID Case Prediction — Example
#
# This notebook demonstrates the data preparation flow: download raw CSVs from Google Drive and preprocess to national-level data. You can run the cells below to execute each step.

# %% [markdown]
# ## 1) Download raw CSVs
#
# Run the downloader (this uses the default Google Drive links defined in `scripts/download_data.py`).
#
# Note: you can run this in the notebook with a shell command or run the helper function below.

# %%
# Option A: run the downloader script (shell)
# !python scripts/download_data.py

# Option B: call the helper function from Python
from utils_data_io import download_and_load_all

# Example: pass a small mapping of names -> Drive links (the project script uses defaults)
gdrive_urls = {
    'cases': 'https://drive.google.com/open?id=1ZfZtoV3PpZblZYES0A5LHCwp54cR8RJL',
    # add other links as needed: 'deaths', 'vaccine', 'mobility'
}
dfs = download_and_load_all(gdrive_urls, data_dir='data')
print('Downloaded and loaded:', list(dfs.keys()))
# Out:
# /Users/harshyadav/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Skipping download for 'cases' - exists at data/cases.csv
# Loading 'cases' from data/cases.csv
# Loaded 3342 rows for 'cases'
# Loading 'deaths' from data/deaths.csv
# Loaded 3342 rows for 'deaths'
# Loading 'mobility' from data/mobility.csv
# Loaded 1847210 rows for 'mobility'
# Loading 'vaccine' from data/vaccine.csv
# Loaded 50595 rows for 'vaccine'
# Downloaded and loaded: ['cases', 'deaths', 'mobility', 'vaccine']
# Loaded 1847210 rows for 'mobility'
# Loading 'vaccine' from data/vaccine.csv
# Loaded 50595 rows for 'vaccine'
# Downloaded and loaded: ['cases', 'deaths', 'mobility', 'vaccine']

# %% [markdown]
# ## 2) Preprocess raw CSVs
#
# This turns county-level JHU time series into a national daily series and merges mobility. It writes `data/processed/national_data.csv`.

# %%
# Run 
# !python3 src/data_processing/preprocess_data.py 
# or
# !python src/data_processing/preprocess_data.py to preprocess the data

# !python3 src/data_processing/preprocess_data.py
# Out:
# Loading cases data from data/cases.csv
# Loaded 3342 rows
# Loading mobility data from data/mobility.csv
# Loaded 3342 rows
# Loading mobility data from data/mobility.csv
# Loaded 1847210 rows
# Loaded 1847210 rows
# Date range: 2020-02-15 00:00:00 to 2022-02-01 00:00:00
#
# Processing cases data...
# /Users/harshyadav/src/umd_classes1/class_project/MSML610/Fall2025/Projects/TutorTask121_GluonTS_COVID_19_Case_Prediction/src/data_processing/preprocess_data.py:27: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   'Date': pd.to_datetime(national_cumulative.index),
# National cases: 1143 days
#
# Processing mobility data...
# Date range: 2020-02-15 00:00:00 to 2022-02-01 00:00:00
#
# Processing cases data...
# ...
