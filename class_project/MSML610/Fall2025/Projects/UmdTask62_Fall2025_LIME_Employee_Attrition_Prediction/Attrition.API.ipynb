# %% [markdown]
# # Attrition API Demo

# %%
from Attrition_utils import AttritionConfig, AttritionService
print('API loaded:', AttritionConfig, AttritionService)
