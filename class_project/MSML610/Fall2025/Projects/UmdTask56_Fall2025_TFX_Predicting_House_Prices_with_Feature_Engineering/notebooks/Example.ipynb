# %% [markdown]
# # House Price Prediction - Project Walkthrough
#
# This notebook provides an end-to-end walkthrough of the house price prediction project using TFX.
#
# **Project Objective:** Build a robust TFX pipeline that predicts house prices based on 80+ features, comparing XGBoost and TensorFlow DNN models.
#
# **Dataset:** Ames Housing Dataset (1,460 training samples, 1,459 test samples)

# %% [markdown]
# ## Setup

# %%
import sys
sys.path.append('..')

import warnings
warnings.filterwarnings('ignore')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Import utilities
from utils import config
from utils import data_utils

# Set plotting style
sns.set_style('whitegrid')
plt.rcParams['figure.figsize'] = (12, 6)

print("Setup complete!")
# Out:
# Setup complete!

# %% [markdown]
# ## Phase 1: Project Foundation ✓
#
# Project structure and configuration complete!

# %%
# Verify project configuration
print(f"Pipeline Name: {config.PIPELINE_NAME}")
print(f"Data Directory: {config.DATA_DIR}")
print(f"Pipeline Root: {config.PIPELINE_ROOT}")
print(f"Target Column: {config.TARGET_COLUMN}")
# Out:
# Pipeline Name: house_price_prediction_pipeline
# Data Directory: c:\Masters\Coursework\Fall 25\MSML610-AML\final_project\umd_classes\class_project\MSML610\Fall2025\Projects\UmdTask56_Fall2025_TFX_Predicting_House_Prices_with_Feature_Engineering\notebooks\..\data
# Pipeline Root: c:\Masters\Coursework\Fall 25\MSML610-AML\final_project\umd_classes\class_project\MSML610\Fall2025\Projects\UmdTask56_Fall2025_TFX_Predicting_House_Prices_with_Feature_Engineering\notebooks\..\pipeline_outputs
# Target Column: SalePrice

# %% [markdown]
# ## Phase 2: Data Ingestion & Validation ✓
#
# In this phase, we:
# 1. Load and explore the data
# 2. Analyze missing values
# 3. Understand feature types (numerical, categorical, ordinal)
# 4. Analyze the target variable
# 5. Implement TFX components: CsvExampleGen, StatisticsGen, SchemaGen

# %% [markdown]
# ### 2.1 Load Data

# %% [markdown]
# ## Phase 3: Feature Engineering
#
# TODO: Implement in Phase 3
# - Handle missing values
# - Scale features
# - Create interaction terms
# - Implement Transform component

# %% [markdown]
# ## Phase 4: Model Training
#
# TODO: Implement in Phase 4
# - Train XGBoost model
# - Train TensorFlow DNN model
# - Compare training metrics

# %% [markdown]
# ## Phase 5: Model Evaluation
#
# TODO: Implement in Phase 5
# - Calculate RMSE and R² scores
# - Perform cross-validation
# - Compare XGBoost vs TensorFlow DNN

# %% [markdown]
# ## Phase 6: Model Deployment
#
# TODO: Implement in Phase 6
# - Deploy best model
# - Generate predictions on test data
# - Create submission file

# %% [markdown]
# ## Results and Insights
#
# TODO: Add final results and insights after completion
