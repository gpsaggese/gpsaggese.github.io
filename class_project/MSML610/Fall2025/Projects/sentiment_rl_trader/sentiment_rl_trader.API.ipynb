# %% [markdown]
# # Sentiment RL Trader — API Notebook
#
# This notebook demonstrates how to use the public API of the Sentiment RL Trader project.
# The goal is to show simple, clean examples of:
#
# - Fetching data
# - Computing sentiment
# - Merging datasets
# - Running the RL agent
#
# All heavy logic is implemented inside Python modules and exposed through a clean API layer.

# %%
# API Notebook: Demonstrating the public API of the project

import wandb
wandb.init(mode="disabled")

from sentiment_rl_trader_utils import (
    load_sentiment_stock_data,
    train_rl_model,
    run_rl_simulation
)

print("API imports loaded successfully!")
# Out:
# API imports loaded successfully!

# %%
merged_df = load_sentiment_stock_data("AAPL")
merged_df.head()
# Out:
#                                                title  \
# 0  This Morning, Wall Street is Bullish on AMAT, ...
# 1  This Morning, Wall Street is Bullish on AMAT, ...
# 2  Ranking the Best "Magnificent Seven" Stocks to...
# 3  Anker Japan、コンパクトサイズのUSB-Cケーブル一体型モバイルバッテリー「Ank...
# 4     5 reasons to buy the Betashares Nasdaq 100 ETF
#
#                                          description  \
# 0  Quick Read\n \n \n Just this morning, UBS upgr...
# 1  Quick Read\n-\nJust this morning, UBS upgraded...
# 2  Key Points\n-\nAmazon isn’t as well-rounded as...
# 3  Anker JapanがコンパクトサイズのUSB-Cケーブル一体型モバイルバッテリー「Ank...
# 4  Want to invest in the best stocks in the world...
#
#                 publishedAt  sentiment                  Datetime        Open  \
# 0 2025-11-25 16:25:08+00:00     0.0000 2025-11-25 16:30:00+00:00  277.820007
# 1 2025-11-25 16:58:49+00:00     0.0000 2025-11-25 16:30:00+00:00  277.820007
# 2 2025-11-25 18:05:52+00:00     0.8442 2025-11-25 18:30:00+00:00  278.765015
# ...

# %%
Q_table = train_rl_model(merged_df)
Q_table.shape
# Out:
# (15, 3)

# %%
results_df, stats = run_rl_simulation(merged_df, Q_table)

results_df.head()
# Out:
# ...
#       RL PERFORMANCE SUMMARY
# ...
# Total Trades:           53
# Long Trades:            16
# Short Trades:           17
# Win Rate:               30.30%
# Final Return:           3.46%
# Max Drawdown:           -0.34%
# Sharpe Ratio:           4.506
# Start Equity:           1.0000
# End Equity:             1.0346
# ...
#                                                title  \
# 0  This Morning, Wall Street is Bullish on AMAT, ...
# 1  Ranking the Best "Magnificent Seven" Stocks to...
# 2  Anker Japan、コンパクトサイズのUSB-Cケーブル一体型モバイルバッテリー「Ank...
# 3  AAPL, NVDA, TSLA: Analyst Dan Ives Lists the 1...
# 4  Google is Winning the AI Race by Stealing Exxo...
#
#                                          description  \
# 0  Quick Read\n-\nJust this morning, UBS upgraded...
# 1  Key Points\n-\nAmazon isn’t as well-rounded as...
# 2  Anker JapanがコンパクトサイズのUSB-Cケーブル一体型モバイルバッテリー「Ank...
# 3  Wedbush Securities analyst Dan Ives has issued...
# 4  Alphabet is transforming into the ‘Big Oil’ of...
#
# ...

# %%
stats
