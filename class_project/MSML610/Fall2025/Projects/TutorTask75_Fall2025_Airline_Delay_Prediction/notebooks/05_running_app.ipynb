# %% [markdown]
# ## Just like in the other notebooks, make sure to select "airline-delay-prediction" kernel on top right of VS-Code

# %% [markdown]
# ### If you cloned my Github repository having the exact same files and same folder names and all, then you can start at this Notebook, 05.ipynb but make sure to run all cells below!!!

# %%
from pathlib import Path
import os
def to_repo_root(start=Path.cwd()):
    for p in [start, *start.parents]:
        if (p/"src").exists() and (p/"requirements.txt").exists():
            os.chdir(p); print("Project root:", p); return
    raise SystemExit("Could not locate project root (needs ./src and ./requirements.txt)")
to_repo_root()
# Out:
# Project root: /Users/nikhilroy/Documents/MSML610/repo

# %%
from src.utils_model import (
    SCHEMA, BASE_CATEGORICAL, BASE_NUMERIC,
    load_model, load_metrics, predict_proba, coerce_schema,
    pick_threshold, load_all_metrics_table, score_row, score_dataframe
)

# %%
# (inside your repo root)
# !conda activate airline-delay-prediction   # or your env name
# !conda install -n airline-delay-predictixwon -c conda-forge openjdk=11 -y || true
# !conda run -n airline-delay-prediction python -m pip install -r requirements.txt
# Out:
# CommandNotFoundError: Your shell has not been properly configured to use 'conda activate'.
# To initialize your shell, run
#
#     $ conda init <SHELL_NAME>
#
# Currently supported shells are:
#   - bash
#   - fish
#   - tcsh
#   - xonsh
#   - zsh
#   - powershell
#
# See 'conda init --help' for more information and options.
#
# IMPORTANT: You may need to close and restart your shell after running 'conda init'.
#
#
#
# EnvironmentLocationNotFound: Not a conda environment: /Users/nikhilroy/opt/anaconda3/envs/airline-delay-predictixwon
#
# Requirement already satisfied: pyspark==3.5.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 2)) (3.5.1)
# Requirement already satisfied: pandas==2.2.3 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: numpy==1.26.4 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 4)) (1.26.4)
# Requirement already satisfied: pyarrow==16.1.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 5)) (16.1.0)
# Requirement already satisfied: meteostat==1.6.8 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 10)) (1.6.8)
# Requirement already satisfied: geopy==2.4.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 11)) (2.4.1)
# Requirement already satisfied: kagglehub==0.3.5 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 12)) (0.3.5)
# Requirement already satisfied: matplotlib==3.9.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 15)) (3.9.2)
# Requirement already satisfied: plotly==5.24.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 16)) (5.24.1)
# Requirement already satisfied: dash==2.18.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 17)) (2.18.2)
# Requirement already satisfied: dash-bootstrap-components==1.6.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 18)) (1.6.0)
# Requirement already satisfied: seaborn==0.13.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 19)) (0.13.2)
# Requirement already satisfied: scikit-learn==1.5.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 22)) (1.5.2)
# Requirement already satisfied: xgboost==2.1.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 23)) (2.1.1)
# Requirement already satisfied: lightgbm==4.5.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 24)) (4.5.0)
# Requirement already satisfied: catboost==1.2.5 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 25)) (1.2.5)
# Requirement already satisfied: imbalanced-learn==0.12.3 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 26)) (0.12.3)
# Requirement already satisfied: shap==0.44.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 27)) (0.44.1)
# Requirement already satisfied: optuna==3.6.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 28)) (3.6.1)
# Requirement already satisfied: tqdm==4.66.5 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 29)) (4.66.5)
# Requirement already satisfied: joblib==1.4.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 31)) (1.4.2)
# Requirement already satisfied: PyYAML==6.0.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 35)) (6.0.2)
# Requirement already satisfied: rich==13.7.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 36)) (13.7.1)
# Requirement already satisfied: streamlit==1.39.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 39)) (1.39.0)
# Requirement already satisfied: jupyterlab==4.2.5 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 43)) (4.2.5)
# Requirement already satisfied: ipykernel==6.29.5 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 44)) (6.29.5)
# Requirement already satisfied: ipython==8.26.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from -r requirements.txt (line 45)) (8.26.0)
# Requirement already satisfied: py4j==0.10.9.7 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from pyspark==3.5.1->-r requirements.txt (line 2)) (0.10.9.7)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from pandas==2.2.3->-r requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from pandas==2.2.3->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from pandas==2.2.3->-r requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: geographiclib<3,>=1.52 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from geopy==2.4.1->-r requirements.txt (line 11)) (2.1)
# Requirement already satisfied: packaging in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from kagglehub==0.3.5->-r requirements.txt (line 12)) (24.2)
# Requirement already satisfied: requests in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from kagglehub==0.3.5->-r requirements.txt (line 12)) (2.32.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 15)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 15)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 15)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 15)) (1.4.9)
# Requirement already satisfied: pillow>=8 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 15)) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from matplotlib==3.9.2->-r requirements.txt (line 15)) (3.2.5)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from plotly==5.24.1->-r requirements.txt (line 16)) (9.1.2)
# Requirement already satisfied: Flask<3.1,>=1.0.4 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from dash==2.18.2->-r requirements.txt (line 17)) (3.0.3)
# Requirement already satisfied: Werkzeug<3.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from dash==2.18.2->-r requirements.txt (line 17)) (3.0.6)
# Requirement already satisfied: dash-html-components==2.0.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from dash==2.18.2->-r requirements.txt (line 17)) (2.0.0)
# Requirement already satisfied: dash-core-components==2.0.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from dash==2.18.2->-r requirements.txt (line 17)) (2.0.0)
# Requirement already satisfied: dash-table==5.0.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from dash==2.18.2->-r requirements.txt (line 17)) (5.0.0)
# Requirement already satisfied: importlib-metadata in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from dash==2.18.2->-r requirements.txt (line 17)) (8.7.0)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from dash==2.18.2->-r requirements.txt (line 17)) (4.15.0)
# Requirement already satisfied: retrying in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from dash==2.18.2->-r requirements.txt (line 17)) (1.4.2)
# Requirement already satisfied: nest-asyncio in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from dash==2.18.2->-r requirements.txt (line 17)) (1.6.0)
# Requirement already satisfied: setuptools in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from dash==2.18.2->-r requirements.txt (line 17)) (80.9.0)
# Requirement already satisfied: scipy>=1.6.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 22)) (1.15.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 22)) (3.6.0)
# Requirement already satisfied: graphviz in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from catboost==1.2.5->-r requirements.txt (line 25)) (0.21)
# Requirement already satisfied: six in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from catboost==1.2.5->-r requirements.txt (line 25)) (1.17.0)
# Requirement already satisfied: slicer==0.0.7 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from shap==0.44.1->-r requirements.txt (line 27)) (0.0.7)
# Requirement already satisfied: numba in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from shap==0.44.1->-r requirements.txt (line 27)) (0.62.1)
# Requirement already satisfied: cloudpickle in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from shap==0.44.1->-r requirements.txt (line 27)) (3.1.2)
# Requirement already satisfied: alembic>=1.5.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from optuna==3.6.1->-r requirements.txt (line 28)) (1.17.1)
# Requirement already satisfied: colorlog in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from optuna==3.6.1->-r requirements.txt (line 28)) (6.10.1)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from optuna==3.6.1->-r requirements.txt (line 28)) (2.0.44)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from rich==13.7.1->-r requirements.txt (line 36)) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from rich==13.7.1->-r requirements.txt (line 36)) (2.19.2)
# Requirement already satisfied: altair<6,>=4.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from streamlit==1.39.0->-r requirements.txt (line 39)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from streamlit==1.39.0->-r requirements.txt (line 39)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from streamlit==1.39.0->-r requirements.txt (line 39)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from streamlit==1.39.0->-r requirements.txt (line 39)) (8.3.0)
# Requirement already satisfied: protobuf<6,>=3.20 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from streamlit==1.39.0->-r requirements.txt (line 39)) (5.29.5)
# Requirement already satisfied: toml<2,>=0.10.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from streamlit==1.39.0->-r requirements.txt (line 39)) (0.10.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from streamlit==1.39.0->-r requirements.txt (line 39)) (3.1.45)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from streamlit==1.39.0->-r requirements.txt (line 39)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from streamlit==1.39.0->-r requirements.txt (line 39)) (6.5.2)
# Requirement already satisfied: async-lru>=1.0.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 43)) (2.0.5)
# Requirement already satisfied: httpx>=0.25.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 43)) (3.1.6)
# Requirement already satisfied: jupyter-core in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 43)) (5.9.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 43)) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 43)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 43)) (2.28.0)
# Requirement already satisfied: notebook-shim>=0.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.2.4)
# Requirement already satisfied: tomli>=1.2.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 43)) (2.3.0)
# Requirement already satisfied: traitlets in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyterlab==4.2.5->-r requirements.txt (line 43)) (5.14.3)
# Requirement already satisfied: appnope in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 44)) (0.1.4)
# Requirement already satisfied: comm>=0.1.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 44)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 44)) (1.8.17)
# Requirement already satisfied: jupyter-client>=6.1.12 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 44)) (8.6.3)
# Requirement already satisfied: matplotlib-inline>=0.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 44)) (0.2.1)
# Requirement already satisfied: psutil in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 44)) (7.1.3)
# Requirement already satisfied: pyzmq>=24 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipykernel==6.29.5->-r requirements.txt (line 44)) (27.1.0)
# Requirement already satisfied: decorator in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipython==8.26.0->-r requirements.txt (line 45)) (5.2.1)
# Requirement already satisfied: jedi>=0.16 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipython==8.26.0->-r requirements.txt (line 45)) (0.19.2)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipython==8.26.0->-r requirements.txt (line 45)) (3.0.52)
# Requirement already satisfied: stack-data in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipython==8.26.0->-r requirements.txt (line 45)) (0.6.3)
# Requirement already satisfied: exceptiongroup in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipython==8.26.0->-r requirements.txt (line 45)) (1.3.0)
# Requirement already satisfied: pexpect>4.3 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from ipython==8.26.0->-r requirements.txt (line 45)) (4.9.0)
# Requirement already satisfied: jsonschema>=3.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit==1.39.0->-r requirements.txt (line 39)) (4.25.1)
# Requirement already satisfied: narwhals>=1.14.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from altair<6,>=4.0->streamlit==1.39.0->-r requirements.txt (line 39)) (2.11.0)
# Requirement already satisfied: itsdangerous>=2.1.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from Flask<3.1,>=1.0.4->dash==2.18.2->-r requirements.txt (line 17)) (2.2.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.39.0->-r requirements.txt (line 39)) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit==1.39.0->-r requirements.txt (line 39)) (5.0.2)
# Requirement already satisfied: anyio>=3.1.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (4.11.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (1.9.0)
# Requirement already satisfied: babel>=2.10 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 43)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.12.1)
# Requirement already satisfied: wcwidth in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython==8.26.0->-r requirements.txt (line 45)) (0.2.14)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from requests->kagglehub==0.3.5->-r requirements.txt (line 12)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from requests->kagglehub==0.3.5->-r requirements.txt (line 12)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from requests->kagglehub==0.3.5->-r requirements.txt (line 12)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from requests->kagglehub==0.3.5->-r requirements.txt (line 12)) (2025.11.12)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from Werkzeug<3.1->dash==2.18.2->-r requirements.txt (line 17)) (3.0.3)
# Requirement already satisfied: Mako in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from alembic>=1.5.0->optuna==3.6.1->-r requirements.txt (line 28)) (1.3.10)
# Requirement already satisfied: sniffio>=1.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (25.1.0)
# Requirement already satisfied: httpcore==1.* in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.16.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jedi>=0.16->ipython==8.26.0->-r requirements.txt (line 45)) (0.8.5)
# Requirement already satisfied: attrs>=22.2.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.39.0->-r requirements.txt (line 39)) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.39.0->-r requirements.txt (line 39)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.39.0->-r requirements.txt (line 39)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit==1.39.0->-r requirements.txt (line 39)) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-core->jupyterlab==4.2.5->-r requirements.txt (line 43)) (4.5.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.1.1)
# Requirement already satisfied: fqdn in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (1.5.1)
# Requirement already satisfied: isoduration in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (1.1.0)
# Requirement already satisfied: uri-template in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (25.10.0)
# Requirement already satisfied: mdurl~=0.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich==13.7.1->-r requirements.txt (line 36)) (0.1.2)
# Requirement already satisfied: beautifulsoup4 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (6.3.0)
# Requirement already satisfied: defusedxml in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (1.5.1)
# Requirement already satisfied: webencodings in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (2.21.2)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from pexpect>4.3->ipython==8.26.0->-r requirements.txt (line 45)) (0.7.0)
# Requirement already satisfied: lark>=1.2.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (1.3.1)
# Requirement already satisfied: greenlet>=1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from sqlalchemy>=1.3.0->optuna==3.6.1->-r requirements.txt (line 28)) (3.2.4)
# Requirement already satisfied: cffi>=1.0.1 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (2.0.0)
# Requirement already satisfied: pycparser in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (2.23)
# Requirement already satisfied: soupsieve>1.2 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (2.8)
# Requirement already satisfied: zipp>=3.20 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from importlib-metadata->dash==2.18.2->-r requirements.txt (line 17)) (3.23.0)
# Requirement already satisfied: arrow>=0.15.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab==4.2.5->-r requirements.txt (line 43)) (1.4.0)
# Requirement already satisfied: llvmlite<0.46,>=0.45.0dev0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from numba->shap==0.44.1->-r requirements.txt (line 27)) (0.45.1)
# Requirement already satisfied: executing>=1.2.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from stack-data->ipython==8.26.0->-r requirements.txt (line 45)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from stack-data->ipython==8.26.0->-r requirements.txt (line 45)) (3.0.0)
# Requirement already satisfied: pure-eval in /Users/nikhilroy/opt/anaconda3/envs/airline-delay-prediction/lib/python3.10/site-packages (from stack-data->ipython==8.26.0->-r requirements.txt (line 45)) (0.2.3)

# %% [markdown]
# ### After running the Below Cell, you will see the app load (might have to swicth tabs/windows or minimize this to see this but it's there! )

# %%
# run the app
# !conda run -n airline-delay-prediction streamlit run src/app.py
# Out:
# ^C
