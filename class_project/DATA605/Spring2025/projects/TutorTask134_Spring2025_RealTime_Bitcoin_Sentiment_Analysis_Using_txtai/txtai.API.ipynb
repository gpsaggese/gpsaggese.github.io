# %% [markdown]
# # Real-Time Bitcoin Sentiment Analysis Using txtai
#
# This project uses real-time news headlines and Bitcoin pricing data to evaluate market sentiment and predict short-term price movements. Tools include:
#
# - [txtai](https://github.com/neuml/txtai) for semantic search and sentiment analysis
# - [NewsAPI](https://newsapi.org/) for real-time crypto-related news
# - [CoinGecko API](https://www.coingecko.com/en/api) for Bitcoin price data
# - Time-series models (ARIMA) for forecasting

# %% [markdown]
# ## 1. Environment Setup
#
# We begin by installing and importing the necessary Python packages. These include:
#
# - `txtai` for semantic search and sentiment analysis
# - `requests` for communicating with external APIs (NewsAPI and CoinGecko)
# - `pandas` for working with tabular data
# - `matplotlib` and `seaborn` for visualizing price and sentiment trends
# - `datetime` for handling timestamps and date alignment
#
# These tools provide the foundation for data ingestion, processing, and visualization in this notebook.

# %%
# import libraries
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# Custom utility functions
from txtai_utils import (
    TxtaiSentimentSearch,
    fetch_bitcoin_headlines,
    analyze_sentiment,
    run_arima_forecast)

# %% [markdown]
# ## 2. Fetch Real-Time News and Analyze Sentiment
#
# We use NewsAPI to fetch live Bitcoin-related news headlines and analyze them using `txtai`'s sentiment pipeline.

# %%
# Set your NewsAPI key
API_KEY = "6e540235a1794f78a804270f2317adf3"  # Replace with your actual NewsAPI key
headlines = fetch_bitcoin_headlines(API_KEY)
today = datetime.utcnow().date()
sentiments = [analyze_sentiment(h) for h in headlines]

# Create sentiment DataFrame
df_sentiment = pd.DataFrame({
    "date": today,
    "headline": headlines,
    "sentiment": sentiments
})
# Out:
# INFO:txtai_utils:Fetching Bitcoin news headlines from NewsAPI...
# INFO:txtai_utils:Fetched 100 headlines.
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: '12 more charged in $263M crypto theft ring that blew it on booze and cars' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Rises While Ethereum, Dogecoin Slip — 'Market Isn't Going To Peak In The Next 6 Months,' Says Popular Analyst' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Coinbase drops 7% on customer breach, SEC probe into user numbers' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'XRP Price Sinks Lower, But Chart Whisperers See a Trap for The Bears' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Treasury Fever Hits The Middle East' → NEGATIVE (0.76)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'New infosec products of the week: May 16, 2025' → POSITIVE (0.97)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Cathie Wood's Block Sale: Ark Sells Bitcoin Play — See What She's Buying Instead' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Wisconsin Pension Fund Sold $300M BlackRock Bitcoin ETF Stake Amid Tariff Turmoil, New Filing Shows' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Near ATH, But Long-Term Holders Aren’t Selling – More Upside Ahead?' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Coinbase SEC Probe and Security Breach Unlikely to Derail Growth, Experts Say' → NEGATIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Ethereum Price Holding Strong — Signs Point to a New Upside Breakout' → POSITIVE (0.63)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Price Looks Upward — Is the Next Leg Higher Starting?' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Brazil fintech gets approval to become a Bitcoin treasury company' → POSITIVE (0.97)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Abu Dhabi sovereign wealth fund, Citadel Advisors double down on BlackRock’s Bitcoin ETF' → NEGATIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Ticking Clock To $200K: Bitwise CIO Predicts Bitcoin’s Price Explosion' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'JP Morgan Sees Bitcoin Outpacing Gold as Crypto Derivatives Market Expands' → NEGATIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Daily RP Yield Signals Strength – Sustainable Growth Expected' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Coinbase says crypto hackers demanded $20m for stolen data' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Tornado Cash dev Roman Storm trial goes ahead with slight trim' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Dips on Weaker Than Expected US Wholesale Prices' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'When Will The XRP Price Explode? Timeline Shared By Crypto Pundit' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Breaking: Man charged over series of threats including at Gather Round, Adelaide Fringe' → POSITIVE (0.86)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Wisconsin Investment Board sold off its Bitcoin ETF stash' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'All good things flow from bitcoin' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Institutional investors juggle bitcoin ETF holdings, US filings show' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Institutional investors juggle bitcoin ETF holdings, US filings show' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Institutional investors juggle bitcoin ETF holdings, US filings show' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'FTX Will Hand Out Over $5 Billion in Bankruptcy Repayments This Month' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Solana Sees Renewed Demand As Capital Flows Turn Positive – Details' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin STH MVRV Trends Higher: Short-Term Holders Eye $118K–$128K Range' → NEGATIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Money Printer Go Brr? Arthur Hayes Thinks It's Coming—And Bitcoin Will Go Nuts' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'KULR Technology Group Stock Tumbles On Q1 Earnings, Company Plans To 'Turbocharge' Bitcoin Acquisition Strategy' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Legacy forex, payments platforms ‘hate’ stablecoin adoption — Kevin O’Leary' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Coinbase Says Criminals Are Demanding $20M Ransom' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Binance holds 102% BTC reserves for 30 straight months – Snapshot reveals' → POSITIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Is Bitcoin Price Turning Bullish Or Bearish? Crypto Analyst Reveals Critical Levels To Watch' → NEGATIVE (0.93)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Price Hits $104,000 As Demand Increases' → NEGATIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'XRP continues to rise, can the XRP Mining platform become your wealth booster?' → POSITIVE (0.93)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Holds Above $100K, Altcoins Slide as Analyst Sees Crypto Rally Into Summer' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Abu Dhabi sovereign wealth fund Mubadala expands Bitcoin exposure via IBIT while Wisconsin fund exits crypto ETF' → NEGATIVE (0.56)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Co-founder says eToro IPO is a testament to market recovery as it aims to become a go-to investment app' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: '"The world is trying to hoard Bitcoin right now" — Eric Trump' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin RICO: Feds charge 13 men in $265 million crypto theft ring' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'FinTech Partnerships Look to Crack Stablecoin On- and Off-Ramp Challenges' → POSITIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Why are SOL Holders Are Eying Ruvi AI (RUVI)?' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Coinbase said cyber crooks stole customer information and demanded $20 million ransom payment' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Holds Above $100K, Altcoins Slide as Analyst Sees Crypto Rally Into Summer' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Crypto Tycoon's Daughter Narrowly Escapes Kidnappers in Paris' → NEGATIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin traders’ evolving view of BTC’s role in every portfolio bolsters $100K support' → POSITIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Could Ruvi AI (RUVI) Be the Next ADA? Analysts Suggest it Will Skyrocket by 20,000% During Altcoin Season' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Strategy’s 500,000 BTC Holdings At Risk As Bitcoin’s 200-Day MA Remains Low At $47,000' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Eric Trump Says Father's Energy Policies Will Help Crypto' → POSITIVE (0.97)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Nova Scotia Power discloses data breach after March security incident' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Eric Trump says father’s energy policies will help crypto' → POSITIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Eric Trump says father's energy policies will help crypto' → POSITIVE (0.97)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'State of Wisconsin unloads over $300 million worth of BlackRock’s Bitcoin ETF' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'BTC Bull Token Presale Soars Toward $6M: Best Crypto Before Bitcoin Hits $110k?' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitdeer Q1 revenue falls more than 40% year-over-year' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Steady As Ethereum, XRP, Dogecoin Climb On Wednesday Morning' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Myriad Moves: Big Bitcoin Buys, NBA Playoff Madness, and Switch 2 Price Switch-Ups' → POSITIVE (0.94)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'FTX estate to start distributing more than $5B on May 30' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'The U.S. has struggled for crypto clarity. Canada may have the answer' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Michael Saylor’s new advice? 'Sell a tooth if you must'' → NEGATIVE (0.62)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Ukraine Finalizing Bill That Could See It Become Next Country To Adopt A National Bitcoin Reserve' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Cipher Mining Announces Participation in Upcoming Investor and Industry Conferences' → POSITIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Fold Holdings Inc. (NASDAQ: FLD) Announces First Quarter 2025 Results' → POSITIVE (0.87)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Crypto Cold War? Trump Says US Is Beating China In Digital Assets' → NEGATIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Peter Schiff admits ‘Bitcoin has a use case’ – But it’s not what you expect' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Primed To Skyrocket to $120,000, According to Crypto Analyst – But There’s a Catch' → POSITIVE (0.93)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Hong Kong Investment Firm Loads Up on BlackRock Bitcoin ETF, Shares Grow to $688M' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Holding Up While Ethereum, XRP, Dogecoin Dip: 'Don't Get Distracted By Short Term Noise,' Trader Says' → NEGATIVE (0.69)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: '‘Really Great Example’: Coinbase Praised for Hack Response Amid $400M Crisis' → POSITIVE (0.93)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Mistakes Were Made From a Wallet Frank DeGods Controls: Founder Wallet Drained as He Exits' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Addentax Takes $800 Million Bet On Bitcoin And Crypto' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin to outperform gold in second half of 2025: JP Morgan' → NEGATIVE (0.97)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin & Solana To Surge To $400k & $420 Respectively? Unlock Passive Income: Bitcoin Cloud Mining with VNBTC Targets the Next Crypto Surge' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Addentax Takes $800 Million Bet On Bitcoin And Crypto' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Eric Trump: Bitcoin Accumulation Is 'A Race To The Top'' → NEGATIVE (0.96)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Solana network activity surge and ‘megaphone’ chart pattern set $210 SOL price target' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Retail investors are back — Can Bitcoin hit a new all-time high?' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Long-Term Holders Supply Sees Second Consecutive Decline After Period Of Growth' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'XRP Moves Into Key Range Against Bitcoin As 3 Major Targets Show Up' → POSITIVE (0.98)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Crypto Whales Offload 1 Million Ether From Exchanges, Bulls Ready To Charge' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Ukraine Eyes National Bitcoin Reserve As Crypto Regulations Take Shape' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Robinhood Rival eToro Goes Live on Nasdaq After Raising $620,000,000 in IPO' → NEGATIVE (0.97)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Popular stock crashes after hack news' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: '$300 million bet? TikTok-connected startup with zero revenue and China links eyes massive stake in Donald Trump’s memecoin' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'The Daily: Coinbase battles extortion attempt as data breach costs could hit $400 million, JPMorgan sees more upside for bitcoin than gold, and more' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'UBS reveals wealthy investors increasing crypto allocations to 5%, echoing Bitwise' → POSITIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Coinbase disclosed a data breach after an extortion attempt' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'DDC Announces Record 2024 Growth and Strategic Bitcoin Reserve Initiative in Shareholder Letter by Founder & CEO Norma Chu' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'AurealOne Leads the Pack Top Crypto Presales Transforming Gaming & Web3!' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Bitcoin Rally Supported By $95,000 Cost Basis Zone: Report' → NEGATIVE (0.99)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Altcoin 'Boom' Sparks LINK's 75% Rally: Will the Momentum Hold As It Tests Key Resistance Levels?' → POSITIVE (0.84)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Floki Made Them Wait for Profits, Bitcoin Solaris Presale Could Deliver Faster: Final Allocation Available' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Ethereum Skyrockets Nearly 10% While Bitcoin ETFs Bleed $91M: What Smart Money Is Doing Now' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Ethereum Building Up Momentum Before a Massive Breakout, Predicts Michaël van de Poppe – Here Are His Targets' → POSITIVE (0.61)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Xoxo to Prague' → POSITIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Analysis: Crypto Heats Up As $35 Billion Enters Market In Under A Month' → NEGATIVE (1.00)
# INFO:txtai_utils:Loading sentiment pipeline...
# INFO:txtai_utils:Analyzed: 'Cardano Founder Targets Crypto’s ‘Three Demons’ With Midnight Network' → NEGATIVE (0.99)

# %% [markdown]
# ## 3. Fetch Bitcoin Price from CoinGecko
#
# We retrieve historical Bitcoin prices from the CoinGecko API to align with the news sentiment data.

# %%
def fetch_bitcoin_prices(days=7):
    url = "https://api.coingecko.com/api/v3/coins/bitcoin/market_chart"
    params = {"vs_currency": "usd", "days": days}
    r = requests.get(url, params=params)
    data = r.json()
    prices = [(datetime.fromtimestamp(ts / 1000).date(), price) for ts, price in data["prices"]]
    return pd.DataFrame(prices, columns=["date", "price"])
# Load price data
df_prices = fetch_bitcoin_prices(days=7)

# %% [markdown]
# ## 4. Merge Sentiment with Price Data
#
# We align news sentiment and price data by merging on the date field.

# %%
df_merge = pd.merge(df_sentiment, df_prices, on="date", how="inner")

# %% [markdown]
# ## 5. Visualize Price and Sentiment Trends
#
# We create two visualizations: a line plot for price and a bar chart for sentiment distribution.

# %%
# Price Line Plot
df_prices.set_index("date")["price"].plot(title="Bitcoin Price (USD)", figsize=(10, 4))
plt.ylabel("Price (USD)")
plt.grid(True)
plt.show()

# Sentiment Bar Plot
df_summary = df_merge.groupby(["date", "sentiment"]).size().unstack().fillna(0)
df_summary.plot(kind="bar", stacked=True, figsize=(10, 4), title="News Sentiment Distribution")
plt.ylabel("Headline Count")
plt.grid(True)
plt.show()

# %% [markdown]
# ## 6. Forecasting Bitcoin Prices with ARIMA
#
# In this section, we use ARIMA to model and forecast Bitcoin prices based on the past 30 days of data.
# We first clean and validate the time series before fitting the model.

# %%
# Fetch 30 days of Bitcoin prices
df_prices = fetch_bitcoin_prices(days=30)

# Remove duplicate dates by grouping and averaging (or use .last() if you prefer)
df_prices = df_prices.groupby("date").mean().reset_index()

# Convert to daily frequency
df_prices = df_prices.set_index("date").asfreq("D")

# Fill missing values by forward filling
df_prices["price"] = df_prices["price"].fillna(method="ffill")

# %%
# print sanity check to make sure prices aren't all zeros or NaNs
print(df_prices.tail())
print("NaN count:", df_prices["price"].isna().sum())
print("Min/Max price:", df_prices["price"].min(), df_prices["price"].max())
# Out:
#                     price
# date
# 2025-05-13  103314.403202
# 2025-05-14  103646.730487
# 2025-05-15  102829.450346
# 2025-05-16  103837.098217
# 2025-05-17  103347.388328
# NaN count: 0
# Min/Max price: 84633.45187606933 104180.8741726982

# %%
# Run ARIMA forecast using the modular function
forecast_df = run_arima_forecast(df_prices, order=(5, 1, 2), steps=7)

# Plot forecasted vs historical data
plt.figure(figsize=(10, 5))
plt.plot(df_prices.index, df_prices["price"], label="Historical Price")
plt.plot(forecast_df.index, forecast_df["forecast"],
         label="Forecasted Price", color="orange", linestyle="--")

plt.title("Bitcoin Price Forecast (Next 7 Days)")
plt.xlabel("Date")
plt.ylabel("Price (USD)")
plt.grid(True)
plt.legend()
plt.xticks(rotation=45)
plt.tight_layout()
plt.subplots_adjust(bottom=0.2)
plt.show()
# Out:
# INFO:txtai_utils:Running ARIMA forecast on 'price' column...
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# /opt/conda/lib/python3.10/site-packages/statsmodels/tsa/statespace/sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# /opt/conda/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# INFO:txtai_utils:Forecasting complete for 7 steps ahead.

# %% [markdown]
# ## Conclusion
#
# In this notebook, we:
#
# - Retrieved real-time Bitcoin news and price data
# - Performed sentiment analysis
# - Merged and visualized sentiment vs. market movement
# - Forecasted future prices using an ARIMA model
