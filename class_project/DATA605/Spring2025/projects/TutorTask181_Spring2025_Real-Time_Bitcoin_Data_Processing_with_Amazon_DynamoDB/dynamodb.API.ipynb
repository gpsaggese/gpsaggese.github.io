# %% [markdown]
# # Bitcoin API
#
# This notebook demonstrates how to interact with the CoinGecko API and AWS DynamoDB for real-time Bitcoin price tracking.
#
# We:
# - Fetch real-time price data from CoinGecko using the `/simple/price` endpoint.
# - Insert the data into a DynamoDB table named `BitcoinPrices`.
# - Use a continuous ingestion script to automate the process.

# %% [markdown]
# ## Step 1: Connect to DynamoDB and List Tables
#
# Establish a connection to AWS DynamoDB and verify available tables.

# %%
import boto3

# Connect to DynamoDB in us-east-1 region
dynamodb = boto3.resource('dynamodb', region_name='us-east-1')

# List and print table names
print("DynamoDB Tables:")
for table in dynamodb.tables.all():
    print("-", table.name)

# %% [markdown]
# ## Step 2: Fetch Real-Time Bitcoin Price from CoinGecko API
#
# Use the helper function `get_bitcoin_price()` to fetch the current BTC price in USD using the CoinGecko `/simple/price` API.

# %%
from template_utils import get_bitcoin_price

btc_price = get_bitcoin_price()
if btc_price:
    print(f"BTC Price Right Now: ${btc_price}")
else:
    print("Failed to fetch BTC price.")

# %% [markdown]
# ## Step 3: Insert Bitcoin Price into DynamoDB
#
# Test inserting one BTC price entry using `insert_bitcoin_price()`.

# %%
from template_utils import insert_bitcoin_price

insert_bitcoin_price()
# Out:
# INFO:template_utils:Fetched Bitcoin price: $84206.0
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# INFO:template_utils:Inserted BTC price $84206.0 at timestamp 1744575538

# %% [markdown]
# ## Step 4: Run Real-Time Ingestion Script
#
# Use the CLI-based `realtime_ingestor.py` script to continuously fetch and insert prices every 60 seconds.
#
# > You can optionally run the script in the background and log output to a file.

# %%
# !python3 realtime_ingestor.py
# Out:
# Starting real-time BTC ingestion (interval: 60s)...
# Press Ctrl+C to stop.
# INFO:template_utils:Fetched Bitcoin price: $83637.0
# INFO:botocore.credentials:Found credentials in shared credentials file: ~/.aws/credentials
# INFO:template_utils:Inserted BTC price $83637.0 at timestamp 1744577021
# INFO:template_utils:Fetched Bitcoin price: $83584.0
# INFO:template_utils:Inserted BTC price $83584.0 at timestamp 1744577081
# INFO:template_utils:Fetched Bitcoin price: $83576.0
# INFO:template_utils:Inserted BTC price $83576.0 at timestamp 1744577141
# INFO:template_utils:Fetched Bitcoin price: $83584.0
# INFO:template_utils:Inserted BTC price $83584.0 at timestamp 1744577201
# INFO:template_utils:Fetched Bitcoin price: $83550.0
# INFO:template_utils:Inserted BTC price $83550.0 at timestamp 1744577262
# INFO:template_utils:Fetched Bitcoin price: $83485.0
# INFO:template_utils:Inserted BTC price $83485.0 at timestamp 1744577322
# INFO:template_utils:Fetched Bitcoin price: $83470.0
# INFO:template_utils:Inserted BTC price $83470.0 at timestamp 1744577382
# INFO:template_utils:Fetched Bitcoin price: $83456.0
# INFO:template_utils:Inserted BTC price $83456.0 at timestamp 1744577442
# INFO:template_utils:Fetched Bitcoin price: $83435.0
# INFO:template_utils:Inserted BTC price $83435.0 at timestamp 1744577503
# INFO:template_utils:Fetched Bitcoin price: $83451.0
# INFO:template_utils:Inserted BTC price $83451.0 at timestamp 1744577563
# INFO:template_utils:Fetched Bitcoin price: $83470.0
# INFO:template_utils:Inserted BTC price $83470.0 at timestamp 1744577623
# INFO:template_utils:Fetched Bitcoin price: $83483.0
# INFO:template_utils:Inserted BTC price $83483.0 at timestamp 1744577683
# INFO:template_utils:Fetched Bitcoin price: $83484.0
# INFO:template_utils:Inserted BTC price $83484.0 at timestamp 1744577744
# INFO:template_utils:Fetched Bitcoin price: $83472.0
# INFO:template_utils:Inserted BTC price $83472.0 at timestamp 1744577805
# INFO:template_utils:Fetched Bitcoin price: $83453.0
# INFO:template_utils:Inserted BTC price $83453.0 at timestamp 1744577865
# INFO:template_utils:Fetched Bitcoin price: $83466.0
# INFO:template_utils:Inserted BTC price $83466.0 at timestamp 1744577925
# INFO:template_utils:Fetched Bitcoin price: $83476.0
# INFO:template_utils:Inserted BTC price $83476.0 at timestamp 1744577985
# INFO:template_utils:Fetched Bitcoin price: $83478.0
# INFO:template_utils:Inserted BTC price $83478.0 at timestamp 1744578045
# INFO:template_utils:Fetched Bitcoin price: $83468.0
# INFO:template_utils:Inserted BTC price $83468.0 at timestamp 1744578106
# INFO:template_utils:Fetched Bitcoin price: $83438.0
# INFO:template_utils:Inserted BTC price $83438.0 at timestamp 1744578166
# INFO:template_utils:Fetched Bitcoin price: $83429.0
# INFO:template_utils:Inserted BTC price $83429.0 at timestamp 1744578226
# INFO:template_utils:Fetched Bitcoin price: $83402.0
# INFO:template_utils:Inserted BTC price $83402.0 at timestamp 1744578286
# INFO:template_utils:Fetched Bitcoin price: $83361.0
# INFO:template_utils:Inserted BTC price $83361.0 at timestamp 1744578347
# INFO:template_utils:Fetched Bitcoin price: $83331.0
# INFO:template_utils:Inserted BTC price $83331.0 at timestamp 1744578407
# INFO:template_utils:Fetched Bitcoin price: $83284.0
# INFO:template_utils:Inserted BTC price $83284.0 at timestamp 1744578467
# INFO:template_utils:Fetched Bitcoin price: $83260.0
# INFO:template_utils:Inserted BTC price $83260.0 at timestamp 1744578527
# INFO:template_utils:Fetched Bitcoin price: $83173.0
# INFO:template_utils:Inserted BTC price $83173.0 at timestamp 1744578587
# INFO:template_utils:Fetched Bitcoin price: $83182.0
# INFO:template_utils:Inserted BTC price $83182.0 at timestamp 1744578648
# INFO:template_utils:Fetched Bitcoin price: $83201.0
# INFO:template_utils:Inserted BTC price $83201.0 at timestamp 1744578708
# INFO:template_utils:Fetched Bitcoin price: $83203.0
# INFO:template_utils:Inserted BTC price $83203.0 at timestamp 1744578768
# INFO:template_utils:Fetched Bitcoin price: $83189.0
# INFO:template_utils:Inserted BTC price $83189.0 at timestamp 1744578828
# INFO:template_utils:Fetched Bitcoin price: $83213.0
# INFO:template_utils:Inserted BTC price $83213.0 at timestamp 1744578889
# INFO:template_utils:Fetched Bitcoin price: $83228.0
# INFO:template_utils:Inserted BTC price $83228.0 at timestamp 1744578949
# INFO:template_utils:Fetched Bitcoin price: $83262.0
# INFO:template_utils:Inserted BTC price $83262.0 at timestamp 1744579009
# INFO:template_utils:Fetched Bitcoin price: $83277.0
# INFO:template_utils:Inserted BTC price $83277.0 at timestamp 1744579069
# INFO:template_utils:Fetched Bitcoin price: $83269.0
# INFO:template_utils:Inserted BTC price $83269.0 at timestamp 1744579129
# INFO:template_utils:Fetched Bitcoin price: $83280.0
# INFO:template_utils:Inserted BTC price $83280.0 at timestamp 1744579190
# INFO:template_utils:Fetched Bitcoin price: $83305.0
# INFO:template_utils:Inserted BTC price $83305.0 at timestamp 1744579250
# INFO:template_utils:Fetched Bitcoin price: $83337.0
# INFO:template_utils:Inserted BTC price $83337.0 at timestamp 1744579310
# INFO:template_utils:Fetched Bitcoin price: $83369.0
# INFO:template_utils:Inserted BTC price $83369.0 at timestamp 1744579370
# INFO:template_utils:Fetched Bitcoin price: $83450.0
# INFO:template_utils:Inserted BTC price $83450.0 at timestamp 1744579430
# INFO:template_utils:Fetched Bitcoin price: $83479.0
# INFO:template_utils:Inserted BTC price $83479.0 at timestamp 1744579491
# INFO:template_utils:Fetched Bitcoin price: $83505.0
# INFO:template_utils:Inserted BTC price $83505.0 at timestamp 1744579551
# INFO:template_utils:Fetched Bitcoin price: $83550.0
# INFO:template_utils:Inserted BTC price $83550.0 at timestamp 1744579611
# INFO:template_utils:Fetched Bitcoin price: $83563.0
# INFO:template_utils:Inserted BTC price $83563.0 at timestamp 1744579671
# INFO:template_utils:Fetched Bitcoin price: $83601.0
# INFO:template_utils:Inserted BTC price $83601.0 at timestamp 1744579732
# INFO:template_utils:Fetched Bitcoin price: $83614.0
# INFO:template_utils:Inserted BTC price $83614.0 at timestamp 1744579792
# INFO:template_utils:Fetched Bitcoin price: $83622.0
# INFO:template_utils:Inserted BTC price $83622.0 at timestamp 1744579852
# INFO:template_utils:Fetched Bitcoin price: $83622.0
# INFO:template_utils:Inserted BTC price $83622.0 at timestamp 1744579912
# INFO:template_utils:Fetched Bitcoin price: $83621.0
# INFO:template_utils:Inserted BTC price $83621.0 at timestamp 1744579973
# INFO:template_utils:Fetched Bitcoin price: $83597.0
# INFO:template_utils:Inserted BTC price $83597.0 at timestamp 1744580034
# INFO:template_utils:Fetched Bitcoin price: $83636.0
# INFO:template_utils:Inserted BTC price $83636.0 at timestamp 1744580095
# INFO:template_utils:Fetched Bitcoin price: $83635.0
# INFO:template_utils:Inserted BTC price $83635.0 at timestamp 1744580155
# INFO:template_utils:Fetched Bitcoin price: $83616.0
# INFO:template_utils:Inserted BTC price $83616.0 at timestamp 1744580215
# INFO:template_utils:Fetched Bitcoin price: $83576.0
# INFO:template_utils:Inserted BTC price $83576.0 at timestamp 1744580275
# INFO:template_utils:Fetched Bitcoin price: $83558.0
# INFO:template_utils:Inserted BTC price $83558.0 at timestamp 1744580337
# INFO:template_utils:Fetched Bitcoin price: $83530.0
# INFO:template_utils:Inserted BTC price $83530.0 at timestamp 1744580397
# INFO:template_utils:Fetched Bitcoin price: $83506.0
# INFO:template_utils:Inserted BTC price $83506.0 at timestamp 1744580457
# INFO:template_utils:Fetched Bitcoin price: $83397.0
# INFO:template_utils:Inserted BTC price $83397.0 at timestamp 1744580517
# INFO:template_utils:Fetched Bitcoin price: $83378.0
# INFO:template_utils:Inserted BTC price $83378.0 at timestamp 1744580577
# INFO:template_utils:Fetched Bitcoin price: $83389.0
# INFO:template_utils:Inserted BTC price $83389.0 at timestamp 1744580638
# INFO:template_utils:Fetched Bitcoin price: $83383.0
# INFO:template_utils:Inserted BTC price $83383.0 at timestamp 1744580698
# INFO:template_utils:Fetched Bitcoin price: $83363.0
# INFO:template_utils:Inserted BTC price $83363.0 at timestamp 1744580758
# INFO:template_utils:Fetched Bitcoin price: $83344.0
# INFO:template_utils:Inserted BTC price $83344.0 at timestamp 1744580818
# INFO:template_utils:Fetched Bitcoin price: $83305.0
# INFO:template_utils:Inserted BTC price $83305.0 at timestamp 1744580879
# INFO:template_utils:Fetched Bitcoin price: $83313.0
# INFO:template_utils:Inserted BTC price $83313.0 at timestamp 1744581027
# INFO:template_utils:Fetched Bitcoin price: $83307.0
# INFO:template_utils:Inserted BTC price $83307.0 at timestamp 1744581088
# INFO:template_utils:Fetched Bitcoin price: $83332.0
# INFO:template_utils:Inserted BTC price $83332.0 at timestamp 1744581148
# INFO:template_utils:Fetched Bitcoin price: $83348.0
# INFO:template_utils:Inserted BTC price $83348.0 at timestamp 1744581208
# INFO:template_utils:Fetched Bitcoin price: $83359.0
# INFO:template_utils:Inserted BTC price $83359.0 at timestamp 1744581268
# INFO:template_utils:Fetched Bitcoin price: $83369.0
# INFO:template_utils:Inserted BTC price $83369.0 at timestamp 1744581329
# INFO:template_utils:Fetched Bitcoin price: $83391.0
# INFO:template_utils:Inserted BTC price $83391.0 at timestamp 1744581389
# INFO:template_utils:Fetched Bitcoin price: $83471.0
# INFO:template_utils:Inserted BTC price $83471.0 at timestamp 1744581449
# INFO:template_utils:Fetched Bitcoin price: $83525.0
# INFO:template_utils:Inserted BTC price $83525.0 at timestamp 1744581509
# INFO:template_utils:Fetched Bitcoin price: $83508.0
# INFO:template_utils:Inserted BTC price $83508.0 at timestamp 1744581569
# INFO:template_utils:Fetched Bitcoin price: $83521.0
# INFO:template_utils:Inserted BTC price $83521.0 at timestamp 1744581630
# INFO:template_utils:Fetched Bitcoin price: $83566.0
# INFO:template_utils:Inserted BTC price $83566.0 at timestamp 1744581690
# INFO:template_utils:Fetched Bitcoin price: $83566.0
# INFO:template_utils:Inserted BTC price $83566.0 at timestamp 1744581750
# INFO:template_utils:Fetched Bitcoin price: $83566.0
# INFO:template_utils:Inserted BTC price $83566.0 at timestamp 1744581810
# INFO:template_utils:Fetched Bitcoin price: $83537.0
# INFO:template_utils:Inserted BTC price $83537.0 at timestamp 1744581871
# INFO:template_utils:Fetched Bitcoin price: $83531.0
# INFO:template_utils:Inserted BTC price $83531.0 at timestamp 1744581931
# INFO:template_utils:Fetched Bitcoin price: $83569.0
# INFO:template_utils:Inserted BTC price $83569.0 at timestamp 1744581991
# INFO:template_utils:Fetched Bitcoin price: $83594.0
# INFO:template_utils:Inserted BTC price $83594.0 at timestamp 1744582051
# INFO:template_utils:Fetched Bitcoin price: $83504.0
# INFO:template_utils:Inserted BTC price $83504.0 at timestamp 1744582112
# ^C
#
# Ingestion loop stopped by user.

# %% [markdown]
# ## Summary
#
# This notebook demonstrates how to access the CoinGecko API for real-time Bitcoin pricing, insert the results into DynamoDB, and test the ingestion process with helper functions and scripts. This pipeline supports serverless processing via DynamoDB Streams and AWS Lambda.
