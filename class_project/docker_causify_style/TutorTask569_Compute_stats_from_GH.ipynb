# %% [markdown]
# CONTENTS:
# - [Compute stats for Team members](#compute-stats-for-team-members)
#   - [Authenticate GitHub Client](#authenticate-github-client)
#   - [Define Time Period](#define-time-period)
#   - [Pre-feth all the data you need in cache](#pre-feth-all-the-data-you-need-in-cache)
#   - [Collect Daily Metrics](#collect-daily-metrics)
#   - [a. Compare users Total performance across all repos since last 3 months](#a.-compare-users-total-performance-across-all-repos-since-last-3-months)
#   - [Performance Evaluation](#performance-evaluation)

# %% [markdown]
# <a name='compute-stats-for-team-members'></a>
# # Compute stats for Team members

# %%
# !sudo /bin/bash -c "(source /venv/bin/activate; pip install --quiet jupyterlab-vim PyGithub)"
# !jupyter labextension enable

# %%
import datetime
import logging
import os

import github_utils

# Enable logging.
logging.basicConfig(level=logging.INFO)
_LOG = logging.getLogger(__name__)

# %%
# importlib.reload(github_utils)
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# <a name='authenticate-github-client'></a>
# ## Authenticate GitHub Client

# %%
os.environ["GITHUB_ACCESS_TOKEN"] = ""

# %%
access_token = os.getenv("GITHUB_ACCESS_TOKEN")
if not access_token:
    _LOG.error("GITHUB_ACCESS_TOKEN not set. Exiting.")
    raise ValueError("Set GITHUB_ACCESS_TOKEN environment variable")
client = github_utils.GitHubAPI(access_token=access_token).get_client()

# %%
users = github_utils.get_github_contributors(
    client, repo_names=["causify-ai/cmamp"]
)
print(users)
# Out:
# {'causify-ai/cmamp': ['gpsaggese', 'gitpaulsmith', 'rheenina', 'DanilYachmenev', 'jsmerix', 'PomazkinG', 'gad26032', 'tamriq', 'plyq', 'mongolianjesus', 'dremdem', 'sonaalKant', 'Sameep2808', 'Shayawnn', 'sonniki', 'samarth9008', 'heanhsok', 'Vedanshu7', 'mindfreakthemon', 'max-rsrch', 'pavolrabatin', 'amrawadk', 'Shaunak01', 'Jd8111997', 'tkpratardan', 'alinakhay', 'Tsallagov', 'neha2801-create', 'katerynak', 'aish-nidhi', 'jayati1397', 'elforeee', 'k0nsta', 'why2000', 'lizvladi', 'Vitaly-Protasov', 'OlgaVakhonina', 'tuimazy2008', 'enotdima', 'cma0416', 'zet694', 'daberezina', 'jserebr', 'pavel-particle', 'k911mipt', 'LibertasSpZ', 'RichardProchadzka', 'sumedha-24', 'andsilver', 'vvandriichuk']}

# %%
users_cmamp = [
    "gpsaggese",
    "gitpaulsmith",
    "rheenina",
    "DanilYachmenev",
    "jsmerix",
    "PomazkinG",
    "tamriq",
    "mongolianjesus",
    "dremdem",
    "Sameep2808",
    "Shayawnn",
    "sonniki",
    "samarth9008",
    "heanhsok",
    "Vedanshu7",
    "pavolrabatin",
    "amrawadk",
    "Shaunak01",
    "Jd8111997",
    "tkpratardan",
    "cma0416",
]

# %% [markdown]
# <a name='define-time-period'></a>
# ## Define Time Period

# %%
# Use a long window for caching and a narrow slice for final analysis
period_full = github_utils.utc_period("2025-01-01", "2025-06-23")
# period_slice = github_utils.utc_period("2025-04-01", "2025-05-31")

# %% [markdown]
# <a name='pre-feth-all-the-data-you-need-in-cache'></a>
# ## Pre-feth all the data you need in cache

# %%
repos = [
    "helpers",
    "tutorials",
    "cmamp",
    "kaizenflow",
    "orange",
    "sports_analytics",
]
org = "causify-ai"

# %%
github_utils.prefetch_periodic_user_repo_data(
    client, org, repos, users_cmamp, period_full
)
# Out:
# Prefetching user-repo data:  28%|███████████████████████████████████████████████████                                                                                                                                     | 35/126 [00:00<00:00, 333.26it/s]
# helpers/gpsaggese: 53 commits, 47 PRs, 53 LOC entries, 12 issues assigned, 3 closed
# helpers/gitpaulsmith: 1 commits, 1 PRs, 1 LOC entries, 0 issues assigned, 0 closed
# helpers/rheenina: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# helpers/DanilYachmenev: 1 commits, 1 PRs, 1 LOC entries, 0 issues assigned, 0 closed
# helpers/jsmerix: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# helpers/PomazkinG: 0 commits, 3 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# helpers/tamriq: 0 commits, 1 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# helpers/mongolianjesus: 1 commits, 1 PRs, 1 LOC entries, 0 issues assigned, 0 closed
# helpers/dremdem: 23 commits, 26 PRs, 23 LOC entries, 15 issues assigned, 14 closed
# helpers/Sameep2808: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# helpers/Shayawnn: 0 commits, 0 PRs, 0 LOC entries, 2 issues assigned, 0 closed
# helpers/sonniki: 52 commits, 53 PRs, 52 LOC entries, 44 issues assigned, 38 closed
# helpers/samarth9008: 1 commits, 2 PRs, 1 LOC entries, 4 issues assigned, 3 closed
# helpers/heanhsok: 83 commits, 89 PRs, 83 LOC entries, 43 issues assigned, 34 closed
# helpers/Vedanshu7: 1 commits, 1 PRs, 1 LOC entries, 2 issues assigned, 2 closed
# helpers/pavolrabatin: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# helpers/amrawadk: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# helpers/Shaunak01: 30 commits, 35 PRs, 30 LOC entries, 40 issues assigned, 34 closed
# helpers/Jd8111997: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# helpers/tkpratardan: 7 commits, 8 PRs, 7 LOC entries, 2 issues assigned, 1 closed
# helpers/cma0416: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/gpsaggese: 8 commits, 7 PRs, 8 LOC entries, 4 issues assigned, 1 closed
# tutorials/gitpaulsmith: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/rheenina: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/DanilYachmenev: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/jsmerix: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/PomazkinG: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/tamriq: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/mongolianjesus: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/dremdem: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/Sameep2808: 1 commits, 0 PRs, 1 LOC entries, 0 issues assigned, 0 closed
# tutorials/Shayawnn: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/sonniki: 8 commits, 5 PRs, 8 LOC entries, 1 issues assigned, 1 closed
# tutorials/samarth9008: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/heanhsok: 7 commits, 8 PRs, 7 LOC entries, 0 issues assigned, 0 closed
# tutorials/Vedanshu7: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/pavolrabatin: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/amrawadk: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/Shaunak01: 5 commits, 6 PRs, 5 LOC entries, 9 issues assigned, 5 closed
# tutorials/Jd8111997: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# tutorials/tkpratardan: 15 commits, 19 PRs, 15 LOC entries, 12 issues assigned, 8 closed
# tutorials/cma0416: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# cmamp/gpsaggese: 14 commits, 11 PRs, 14 LOC entries, 17 issues assigned, 5 closed
# cmamp/gitpaulsmith: 3 commits, 4 PRs, 3 LOC entries, 4 issues assigned, 2 closed
# cmamp/rheenina: 50 commits, 62 PRs, 50 LOC entries, 68 issues assigned, 58 closed
# cmamp/DanilYachmenev: 9 commits, 13 PRs, 9 LOC entries, 16 issues assigned, 13 closed
# cmamp/jsmerix: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# cmamp/PomazkinG: 24 commits, 36 PRs, 24 LOC entries, 44 issues assigned, 32 closed
# cmamp/tamriq: 37 commits, 44 PRs, 37 LOC entries, 41 issues assigned, 34 closed
# cmamp/mongolianjesus: 54 commits, 70 PRs, 54 LOC entries, 59 issues assigned, 51 closed
# cmamp/dremdem: 9 commits, 24 PRs, 9 LOC entries, 22 issues assigned, 16 closed
# cmamp/Sameep2808: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# cmamp/Shayawnn: 43 commits, 44 PRs, 43 LOC entries, 57 issues assigned, 31 closed
# cmamp/sonniki: 37 commits, 37 PRs, 37 LOC entries, 32 issues assigned, 27 closed
# cmamp/samarth9008: 19 commits, 26 PRs, 19 LOC entries, 39 issues assigned, 31 closed
# cmamp/heanhsok: 89 commits, 115 PRs, 89 LOC entries, 133 issues assigned, 94 closed
# cmamp/Vedanshu7: 50 commits, 81 PRs, 50 LOC entries, 77 issues assigned, 68 closed
# cmamp/pavolrabatin: 20 commits, 23 PRs, 20 LOC entries, 0 issues assigned, 0 closed
# cmamp/amrawadk: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# Prefetching user-repo data: 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 126/126 [00:00<00:00, 316.40it/s]
# INFO:github_utils:Prefetched 126 user-repo combos in 0.40 seconds for period 2025-01-01 00:00:00+00:00 to 2025-06-23 00:00:00+00:00.
# cmamp/Shaunak01: 33 commits, 39 PRs, 33 LOC entries, 54 issues assigned, 43 closed
# cmamp/Jd8111997: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# cmamp/tkpratardan: 11 commits, 13 PRs, 11 LOC entries, 16 issues assigned, 5 closed
# cmamp/cma0416: 5 commits, 18 PRs, 5 LOC entries, 23 issues assigned, 8 closed
# kaizenflow/gpsaggese: 0 commits, 0 PRs, 0 LOC entries, 1 issues assigned, 0 closed
# kaizenflow/gitpaulsmith: 1 commits, 1 PRs, 1 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/rheenina: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/DanilYachmenev: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/jsmerix: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/PomazkinG: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/tamriq: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/mongolianjesus: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/dremdem: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/Sameep2808: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/Shayawnn: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/sonniki: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/samarth9008: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/heanhsok: 1 commits, 1 PRs, 1 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/Vedanshu7: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/pavolrabatin: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/amrawadk: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/Shaunak01: 1 commits, 1 PRs, 1 LOC entries, 1 issues assigned, 1 closed
# kaizenflow/Jd8111997: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/tkpratardan: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# kaizenflow/cma0416: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# orange/gpsaggese: 5 commits, 0 PRs, 5 LOC entries, 0 issues assigned, 0 closed
# orange/gitpaulsmith: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# orange/rheenina: 1 commits, 1 PRs, 1 LOC entries, 0 issues assigned, 0 closed
# orange/DanilYachmenev: 16 commits, 2 PRs, 16 LOC entries, 0 issues assigned, 0 closed
# orange/jsmerix: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# orange/PomazkinG: 0 commits, 1 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# orange/tamriq: 5 commits, 3 PRs, 5 LOC entries, 0 issues assigned, 0 closed
# orange/mongolianjesus: 0 commits, 1 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# orange/dremdem: 1 commits, 2 PRs, 1 LOC entries, 1 issues assigned, 0 closed
# orange/Sameep2808: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# orange/Shayawnn: 1 commits, 0 PRs, 1 LOC entries, 0 issues assigned, 0 closed
# orange/sonniki: 2 commits, 1 PRs, 2 LOC entries, 0 issues assigned, 0 closed
# orange/samarth9008: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# orange/heanhsok: 29 commits, 18 PRs, 29 LOC entries, 2 issues assigned, 2 closed
# orange/Vedanshu7: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# orange/pavolrabatin: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# orange/amrawadk: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# orange/Shaunak01: 0 commits, 0 PRs, 0 LOC entries, 2 issues assigned, 2 closed
# orange/Jd8111997: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# orange/tkpratardan: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# orange/cma0416: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/gpsaggese: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/gitpaulsmith: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/rheenina: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/DanilYachmenev: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/jsmerix: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/PomazkinG: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/tamriq: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/mongolianjesus: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/dremdem: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/Sameep2808: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/Shayawnn: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/sonniki: 2 commits, 1 PRs, 2 LOC entries, 1 issues assigned, 1 closed
# sports_analytics/samarth9008: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/heanhsok: 6 commits, 5 PRs, 6 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/Vedanshu7: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/pavolrabatin: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/amrawadk: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/Shaunak01: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/Jd8111997: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/tkpratardan: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed
# sports_analytics/cma0416: 0 commits, 0 PRs, 0 LOC entries, 0 issues assigned, 0 closed

# %% [markdown]
# <a name='collect-daily-metrics'></a>
# ## Collect Daily Metrics

# %%
combined_df = github_utils.collect_all_metrics(
    client, org, repos, users_cmamp, period_full
)

# %% [markdown]
# <a name='a.-compare-users-total-performance-across-all-repos-since-last-3-months'></a>
# ## a. Compare users Total performance across all repos since last 3 months

# %%
github_utils.plot_multi_metrics_totals_by_user(
    combined=combined_df,
    metrics=["prs", "issues_closed"],
    users=users_cmamp,
    repos=repos,
    start=datetime.datetime(2025, 3, 1),
    end=datetime.datetime(2025, 6, 23),
)

# %% [markdown]
# <a name='performance-evaluation'></a>
# ## Performance Evaluation

# %%
# Step 0: Define your slice
users = users_cmamp
repos = repos
metrics = ["prs", "issues_closed"]

# Step 1: Summarize total metrics across users/repos
summary_users = github_utils.summarize_users_across_repos(
    combined_df, users=users, repos=repos
)

# Step 2: Add z-scores and percentiles
z_df = github_utils.compute_z_scores(summary_users, metrics)
stats = github_utils.compute_percentile_ranks(z_df, metrics)

# Step 3: Visualize — will automatically pick up all *_z or *_pctile columns
github_utils.visualize_user_metric_comparison(stats, score_type="z")
github_utils.visualize_user_metric_comparison(stats, score_type="percentile")
# Out:
# <style type="text/css">
# #T_ef480_row0_col0, #T_ef480_row11_col1 {
#   background-color: #c62027;
#   color: #f1f1f1;
# }
# #T_ef480_row0_col1 {
#   background-color: #d62f27;
#   color: #f1f1f1;
# }
# #T_ef480_row1_col0, #T_ef480_row1_col1, #T_ef480_row3_col0, #T_ef480_row3_col1, #T_ef480_row7_col0, #T_ef480_row7_col1, #T_ef480_row13_col0, #T_ef480_row13_col1, #T_ef480_row15_col1 {
#   background-color: #a50026;
#   color: #f1f1f1;
# }
# #T_ef480_row2_col0, #T_ef480_row20_col0 {
#   background-color: #eb5a3a;
#   color: #f1f1f1;
# }
# #T_ef480_row2_col1 {
#   background-color: #f88c51;
#   color: #f1f1f1;
# }
# #T_ef480_row4_col0 {
#   background-color: #fdc372;
#   color: #000000;
# }
# #T_ef480_row4_col1 {
#   background-color: #bde379;
#   color: #000000;
# }
# #T_ef480_row5_col0 {
#   background-color: #ef633f;
#   color: #f1f1f1;
# }
# #T_ef480_row5_col1 {
#   background-color: #f8864f;
#   color: #f1f1f1;
# }
# #T_ef480_row6_col0 {
#   background-color: #fdc574;
#   color: #000000;
# }
# #T_ef480_row6_col1 {
#   background-color: #f1f9ac;
#   color: #000000;
# }
# #T_ef480_row8_col0 {
#   background-color: #ca2427;
#   color: #f1f1f1;
# }
# #T_ef480_row8_col1 {
#   background-color: #c21c27;
#   color: #f1f1f1;
# }
# #T_ef480_row9_col0 {
#   background-color: #f67a49;
#   color: #f1f1f1;
# }
# #T_ef480_row9_col1 {
#   background-color: #f7814c;
#   color: #f1f1f1;
# }
# #T_ef480_row10_col0 {
#   background-color: #b10b26;
#   color: #f1f1f1;
# }
# #T_ef480_row10_col1 {
#   background-color: #ab0626;
#   color: #f1f1f1;
# }
# #T_ef480_row11_col0 {
#   background-color: #fb9d59;
#   color: #000000;
# }
# #T_ef480_row12_col0, #T_ef480_row12_col1 {
#   background-color: #006837;
#   color: #f1f1f1;
# }
# #T_ef480_row14_col0 {
#   background-color: #fdb163;
#   color: #000000;
# }
# #T_ef480_row14_col1 {
#   background-color: #fedc88;
#   color: #000000;
# }
# #T_ef480_row15_col0 {
#   background-color: #d42d27;
#   color: #f1f1f1;
# }
# #T_ef480_row16_col0 {
#   background-color: #fa9857;
#   color: #000000;
# }
# #T_ef480_row16_col1 {
#   background-color: #feefa3;
#   color: #000000;
# }
# #T_ef480_row17_col0 {
#   background-color: #dc3b2c;
#   color: #f1f1f1;
# }
# #T_ef480_row17_col1, #T_ef480_row19_col1 {
#   background-color: #f99355;
#   color: #000000;
# }
# #T_ef480_row18_col0 {
#   background-color: #fee491;
#   color: #000000;
# }
# #T_ef480_row18_col1 {
#   background-color: #fafdb8;
#   color: #000000;
# }
# #T_ef480_row19_col0 {
#   background-color: #f47044;
#   color: #f1f1f1;
# }
# #T_ef480_row20_col1 {
#   background-color: #d93429;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ef480">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef480_level0_col0" class="col_heading level0 col0" >prs_z</th>
#       <th id="T_ef480_level0_col1" class="col_heading level0 col1" >issues_closed_z</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >user</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef480_level0_row0" class="row_heading level0 row0" >DanilYachmenev</th>
#       <td id="T_ef480_row0_col0" class="data row0 col0" >-0.61</td>
#       <td id="T_ef480_row0_col1" class="data row0 col1" >-0.54</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row1" class="row_heading level0 row1" >Jd8111997</th>
#       <td id="T_ef480_row1_col0" class="data row1 col0" >-0.92</td>
#       <td id="T_ef480_row1_col1" class="data row1 col1" >-0.92</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row2" class="row_heading level0 row2" >PomazkinG</th>
#       <td id="T_ef480_row2_col0" class="data row2 col0" >-0.16</td>
#       <td id="T_ef480_row2_col1" class="data row2 col1" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row3" class="row_heading level0 row3" >Sameep2808</th>
#       <td id="T_ef480_row3_col0" class="data row3 col0" >-0.92</td>
#       <td id="T_ef480_row3_col1" class="data row3 col1" >-0.92</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row4" class="row_heading level0 row4" >Shaunak01</th>
#       <td id="T_ef480_row4_col0" class="data row4 col0" >0.63</td>
#       <td id="T_ef480_row4_col1" class="data row4 col1" >1.54</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row5" class="row_heading level0 row5" >Shayawnn</th>
#       <td id="T_ef480_row5_col0" class="data row5 col0" >-0.08</td>
#       <td id="T_ef480_row5_col1" class="data row5 col1" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row6" class="row_heading level0 row6" >Vedanshu7</th>
#       <td id="T_ef480_row6_col0" class="data row6 col0" >0.64</td>
#       <td id="T_ef480_row6_col1" class="data row6 col1" >1.10</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row7" class="row_heading level0 row7" >amrawadk</th>
#       <td id="T_ef480_row7_col0" class="data row7 col0" >-0.92</td>
#       <td id="T_ef480_row7_col1" class="data row7 col1" >-0.92</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row8" class="row_heading level0 row8" >cma0416</th>
#       <td id="T_ef480_row8_col0" class="data row8 col0" >-0.57</td>
#       <td id="T_ef480_row8_col1" class="data row8 col1" >-0.69</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row9" class="row_heading level0 row9" >dremdem</th>
#       <td id="T_ef480_row9_col0" class="data row9 col0" >0.07</td>
#       <td id="T_ef480_row9_col1" class="data row9 col1" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row10" class="row_heading level0 row10" >gitpaulsmith</th>
#       <td id="T_ef480_row10_col0" class="data row10 col0" >-0.80</td>
#       <td id="T_ef480_row10_col1" class="data row10 col1" >-0.86</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row11" class="row_heading level0 row11" >gpsaggese</th>
#       <td id="T_ef480_row11_col0" class="data row11 col0" >0.32</td>
#       <td id="T_ef480_row11_col1" class="data row11 col1" >-0.66</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row12" class="row_heading level0 row12" >heanhsok</th>
#       <td id="T_ef480_row12_col0" class="data row12 col0" >3.58</td>
#       <td id="T_ef480_row12_col1" class="data row12 col1" >2.84</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row13" class="row_heading level0 row13" >jsmerix</th>
#       <td id="T_ef480_row13_col0" class="data row13 col0" >-0.92</td>
#       <td id="T_ef480_row13_col1" class="data row13 col1" >-0.92</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row14" class="row_heading level0 row14" >mongolianjesus</th>
#       <td id="T_ef480_row14_col0" class="data row14 col0" >0.45</td>
#       <td id="T_ef480_row14_col1" class="data row14 col1" >0.55</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row15" class="row_heading level0 row15" >pavolrabatin</th>
#       <td id="T_ef480_row15_col0" class="data row15 col0" >-0.48</td>
#       <td id="T_ef480_row15_col1" class="data row15 col1" >-0.92</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row16" class="row_heading level0 row16" >rheenina</th>
#       <td id="T_ef480_row16_col0" class="data row16 col0" >0.28</td>
#       <td id="T_ef480_row16_col1" class="data row16 col1" >0.76</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row17" class="row_heading level0 row17" >samarth9008</th>
#       <td id="T_ef480_row17_col0" class="data row17 col0" >-0.38</td>
#       <td id="T_ef480_row17_col1" class="data row17 col1" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row18" class="row_heading level0 row18" >sonniki</th>
#       <td id="T_ef480_row18_col0" class="data row18 col0" >0.93</td>
#       <td id="T_ef480_row18_col1" class="data row18 col1" >1.02</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row19" class="row_heading level0 row19" >tamriq</th>
#       <td id="T_ef480_row19_col0" class="data row19 col0" >-0.00</td>
#       <td id="T_ef480_row19_col1" class="data row19 col1" >0.06</td>
#     </tr>
#     <tr>
#       <th id="T_ef480_level0_row20" class="row_heading level0 row20" >tkpratardan</th>
#       <td id="T_ef480_row20_col0" class="data row20 col0" >-0.16</td>
#       <td id="T_ef480_row20_col1" class="data row20 col1" >-0.51</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_9b573_row0_col0 {
#   background-color: #d6efd0;
#   color: #000000;
# }
# #T_9b573_row0_col1 {
#   background-color: #aedea7;
#   color: #000000;
# }
# #T_9b573_row1_col0, #T_9b573_row1_col1, #T_9b573_row3_col0, #T_9b573_row3_col1, #T_9b573_row7_col0, #T_9b573_row7_col1, #T_9b573_row13_col0, #T_9b573_row13_col1, #T_9b573_row15_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# #T_9b573_row2_col0, #T_9b573_row20_col0 {
#   background-color: #8dd08a;
#   color: #000000;
# }
# #T_9b573_row2_col1 {
#   background-color: #5db96b;
#   color: #f1f1f1;
# }
# #T_9b573_row4_col0 {
#   background-color: #0a7633;
#   color: #f1f1f1;
# }
# #T_9b573_row4_col1 {
#   background-color: #005622;
#   color: #f1f1f1;
# }
# #T_9b573_row5_col0 {
#   background-color: #6ec173;
#   color: #000000;
# }
# #T_9b573_row5_col1 {
#   background-color: #75c477;
#   color: #000000;
# }
# #T_9b573_row6_col0 {
#   background-color: #006729;
#   color: #f1f1f1;
# }
# #T_9b573_row6_col1 {
#   background-color: #00682a;
#   color: #f1f1f1;
# }
# #T_9b573_row8_col0 {
#   background-color: #c9eac2;
#   color: #000000;
# }
# #T_9b573_row8_col1 {
#   background-color: #ceecc8;
#   color: #000000;
# }
# #T_9b573_row9_col0 {
#   background-color: #42ab5d;
#   color: #f1f1f1;
# }
# #T_9b573_row9_col1 {
#   background-color: #88ce87;
#   color: #000000;
# }
# #T_9b573_row10_col0 {
#   background-color: #e3f4de;
#   color: #000000;
# }
# #T_9b573_row10_col1 {
#   background-color: #dbf1d6;
#   color: #000000;
# }
# #T_9b573_row11_col0 {
#   background-color: #289049;
#   color: #f1f1f1;
# }
# #T_9b573_row11_col1 {
#   background-color: #bee5b8;
#   color: #000000;
# }
# #T_9b573_row12_col0, #T_9b573_row12_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_9b573_row14_col0 {
#   background-color: #19833e;
#   color: #f1f1f1;
# }
# #T_9b573_row14_col1 {
#   background-color: #2a924a;
#   color: #f1f1f1;
# }
# #T_9b573_row15_col0 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_9b573_row16_col0 {
#   background-color: #359e53;
#   color: #f1f1f1;
# }
# #T_9b573_row16_col1 {
#   background-color: #1a843f;
#   color: #f1f1f1;
# }
# #T_9b573_row17_col0 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_9b573_row17_col1, #T_9b573_row19_col1 {
#   background-color: #3ea75a;
#   color: #f1f1f1;
# }
# #T_9b573_row18_col0 {
#   background-color: #005522;
#   color: #f1f1f1;
# }
# #T_9b573_row18_col1 {
#   background-color: #0b7734;
#   color: #f1f1f1;
# }
# #T_9b573_row19_col0 {
#   background-color: #58b668;
#   color: #f1f1f1;
# }
# #T_9b573_row20_col1 {
#   background-color: #9cd797;
#   color: #000000;
# }
# </style>
# <table id="T_9b573">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9b573_level0_col0" class="col_heading level0 col0" >prs_pctile</th>
#       <th id="T_9b573_level0_col1" class="col_heading level0 col1" >issues_closed_pctile</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >user</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9b573_level0_row0" class="row_heading level0 row0" >DanilYachmenev</th>
#       <td id="T_9b573_row0_col0" class="data row0 col0" >0.29</td>
#       <td id="T_9b573_row0_col1" class="data row0 col1" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row1" class="row_heading level0 row1" >Jd8111997</th>
#       <td id="T_9b573_row1_col0" class="data row1 col0" >0.12</td>
#       <td id="T_9b573_row1_col1" class="data row1 col1" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row2" class="row_heading level0 row2" >PomazkinG</th>
#       <td id="T_9b573_row2_col0" class="data row2 col0" >0.50</td>
#       <td id="T_9b573_row2_col1" class="data row2 col1" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row3" class="row_heading level0 row3" >Sameep2808</th>
#       <td id="T_9b573_row3_col0" class="data row3 col0" >0.12</td>
#       <td id="T_9b573_row3_col1" class="data row3 col1" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row4" class="row_heading level0 row4" >Shaunak01</th>
#       <td id="T_9b573_row4_col0" class="data row4 col0" >0.86</td>
#       <td id="T_9b573_row4_col1" class="data row4 col1" >0.95</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row5" class="row_heading level0 row5" >Shayawnn</th>
#       <td id="T_9b573_row5_col0" class="data row5 col0" >0.57</td>
#       <td id="T_9b573_row5_col1" class="data row5 col1" >0.57</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row6" class="row_heading level0 row6" >Vedanshu7</th>
#       <td id="T_9b573_row6_col0" class="data row6 col0" >0.90</td>
#       <td id="T_9b573_row6_col1" class="data row6 col1" >0.90</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row7" class="row_heading level0 row7" >amrawadk</th>
#       <td id="T_9b573_row7_col0" class="data row7 col0" >0.12</td>
#       <td id="T_9b573_row7_col1" class="data row7 col1" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row8" class="row_heading level0 row8" >cma0416</th>
#       <td id="T_9b573_row8_col0" class="data row8 col0" >0.33</td>
#       <td id="T_9b573_row8_col1" class="data row8 col1" >0.33</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row9" class="row_heading level0 row9" >dremdem</th>
#       <td id="T_9b573_row9_col0" class="data row9 col0" >0.67</td>
#       <td id="T_9b573_row9_col1" class="data row9 col1" >0.52</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row10" class="row_heading level0 row10" >gitpaulsmith</th>
#       <td id="T_9b573_row10_col0" class="data row10 col0" >0.24</td>
#       <td id="T_9b573_row10_col1" class="data row10 col1" >0.29</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row11" class="row_heading level0 row11" >gpsaggese</th>
#       <td id="T_9b573_row11_col0" class="data row11 col0" >0.76</td>
#       <td id="T_9b573_row11_col1" class="data row11 col1" >0.38</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row12" class="row_heading level0 row12" >heanhsok</th>
#       <td id="T_9b573_row12_col0" class="data row12 col0" >1.00</td>
#       <td id="T_9b573_row12_col1" class="data row12 col1" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row13" class="row_heading level0 row13" >jsmerix</th>
#       <td id="T_9b573_row13_col0" class="data row13 col0" >0.12</td>
#       <td id="T_9b573_row13_col1" class="data row13 col1" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row14" class="row_heading level0 row14" >mongolianjesus</th>
#       <td id="T_9b573_row14_col0" class="data row14 col0" >0.81</td>
#       <td id="T_9b573_row14_col1" class="data row14 col1" >0.76</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row15" class="row_heading level0 row15" >pavolrabatin</th>
#       <td id="T_9b573_row15_col0" class="data row15 col0" >0.38</td>
#       <td id="T_9b573_row15_col1" class="data row15 col1" >0.14</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row16" class="row_heading level0 row16" >rheenina</th>
#       <td id="T_9b573_row16_col0" class="data row16 col0" >0.71</td>
#       <td id="T_9b573_row16_col1" class="data row16 col1" >0.81</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row17" class="row_heading level0 row17" >samarth9008</th>
#       <td id="T_9b573_row17_col0" class="data row17 col0" >0.43</td>
#       <td id="T_9b573_row17_col1" class="data row17 col1" >0.69</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row18" class="row_heading level0 row18" >sonniki</th>
#       <td id="T_9b573_row18_col0" class="data row18 col0" >0.95</td>
#       <td id="T_9b573_row18_col1" class="data row18 col1" >0.86</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row19" class="row_heading level0 row19" >tamriq</th>
#       <td id="T_9b573_row19_col0" class="data row19 col0" >0.62</td>
#       <td id="T_9b573_row19_col1" class="data row19 col1" >0.69</td>
#     </tr>
#     <tr>
#       <th id="T_9b573_level0_row20" class="row_heading level0 row20" >tkpratardan</th>
#       <td id="T_9b573_row20_col0" class="data row20 col0" >0.50</td>
#       <td id="T_9b573_row20_col1" class="data row20 col1" >0.48</td>
#     </tr>
#   </tbody>
# </table>
