# %%
# Cell 1: Import
from semantic_search_utils import SemanticSearchEngine, load_wikipedia_data

# %%
# Cell 2: Load data
texts = load_wikipedia_data("data_sample.parquet", max_articles=1000)
print(f"Loaded {len(texts)} articles")
# Out:
# Loaded 1000 articles

# %%
engine = SemanticSearchEngine()
engine.load_model()

# %%
engine.index_documents(texts)
# Out:
# Batches:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
results = engine.search("famous tower in Paris", top_k=3)
for r in results:
    print(f"Score: {r.score:.3f} | {r.text[:100]}...")
# Out:
# Score: 0.316 | Estadio de fútbol Farid Richa is a multi-use stadium in Barquisimeto, Venezuela. It is currently use...
# Score: 0.289 | Vergier de La Rochejacquelein is the name of an ancient French noble family of the Vendée, celebrate...
# Score: 0.274 | Eisenberg Castle is a medieval hilltop castle ruin north of Pfronten, Bavaria, Germany built in the ...

# %%
results = engine.search("artificial intelligence", top_k=3)
for r in results:
    print(f"Score: {r.score:.3f} | {r.text[:100]}...")
# Out:
# Score: 0.275 | Anthony Pratt may refer to: * Anthony Pratt (businessman) (born 1960), Australian billionaire, execu...
# Score: 0.269 | Abdulmotaleb El Saddik (born March 21, 1969) is a Lebanese–Canadian computer engineer and scientist,...
# Score: 0.257 | Autoassociative memory, also known as auto-association memory or an autoassociation network, is any ...
